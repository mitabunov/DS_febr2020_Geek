# %% [markdown]
# ## <center>Курсовой проект <a class="anchor" id="course_project"></a><center>

# %% [markdown]
# **Содержание**
#
# * [Введение](#theory)
# * [Обзор данных](#course_project_review)
# * [Подготовка модели](#make_model)
# * [Применение модели](#practice)

# %% [markdown]
# ## Введение<a class="anchor" id="theory"></a>

# %% [markdown]
# **Задача**
#
# Требуется, на основании имеющихся данных о клиентах банка, построить модель, используя обучающий датасет, для прогнозирования невыполнения долговых обязательств по текущему кредиту. Выполнить прогноз для примеров из тестового датасета.
#
# **Наименование файлов с данными**
#
# course_project_train.csv - обучающий датасет<br>
# course_project_test.csv - тестовый датасет
#
# **Целевая переменная**
#
# Credit Default - факт невыполнения кредитных обязательств
#
# **Метрика качества**
#
# F1-score (sklearn.metrics.f1_score)
#
# **Требования к решению**
#
# *Целевая метрика*
# * F1 > 0.5
# * Метрика оценивается по качеству прогноза для главного класса (1 - просрочка по кредиту)

# %%
import pandas as pd
import numpy as np
import pickle
import random

import missingno as msno
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
from scipy.stats import shapiro
from scipy.stats import probplot
from scipy.stats import ttest_ind, mannwhitneyu
from scipy.stats import chi2_contingency
from statsmodels.stats.weightstats import zconfint

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, cross_val_score, learning_curve
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb, lightgbm as lgbm, catboost as catb

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, cross_val_score, learning_curve
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score
from catboost import Pool, CatBoostClassifier, EFstrType
from sklearn.neighbors import KNeighborsClassifier

import xgboost as xgb, lightgbm as lgbm, catboost as catb
from collections import Counter
from scipy.stats import randint,uniform

# %%
from imblearn.datasets import make_imbalance
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost

# %%
#!jupyter nbextension enable --py widgetsnbextension --user

# %%
#pip install ipywidgets

# %% [markdown]
# ### Обзор данных<a class="anchor" id="course_project_review"></a>

# %%
# input
TRAIN_PATH = '/home/mikhail/Рабочий стол/DS_02/course_project/course_project_train.csv'
TEST_PATH = '/home/mikhail/Рабочий стол/DS_02/course_project/course_project_test.csv'

SCALER_FILE_PATH = '/home/mikhail/Рабочий стол/DS_02/scaler.pkl'

MODEL_FILE_PATH = '/home/mikhail/Рабочий стол/DS_02/model_02.pkl'

# %%
df_train = pd.read_csv(TRAIN_PATH)
df_train
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0          Own Home       482087.0                  NaN        0.0
# 1          Own Home      1025487.0            10+ years        0.0
# 2     Home Mortgage       751412.0              8 years        0.0
# 3          Own Home       805068.0              6 years        0.0
# 4              Rent       776264.0              8 years        0.0
# ...             ...            ...                  ...        ...
# 7495           Rent       402192.0             < 1 year        0.0
# 7496  Home Mortgage      1533984.0               1 year        0.0
# 7497           Rent      1878910.0              6 years        0.0
# 7498  Home Mortgage            NaN                  NaN        0.0
# 7499           Rent            NaN              4 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                     26.3             685960.0
# 1                        15.0                     15.3            1181730.0
# 2                        11.0                     35.0            1182434.0
# 3                         8.0                     22.5             147400.0
# 4                        13.0                     13.6             385836.0
# ...                       ...                      ...                  ...
# 7495                      3.0                      8.5             107866.0
# 7496                     10.0                     26.5             686312.0
# 7497                     12.0                     32.1            1778920.0
# 7498                     21.0                     26.5            1141250.0
# 7499                      8.0                      9.4             480832.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           1.0                           NaN           1.0
# 1                           0.0                           NaN           0.0
# 2                           0.0                           NaN           0.0
# 3                           1.0                           NaN           1.0
# 4                           1.0                           NaN           0.0
# ...                         ...                           ...           ...
# 7495                        0.0                           NaN           0.0
# 7496                        0.0                          43.0           0.0
# 7497                        0.0                           NaN           0.0
# 7498                        0.0                           NaN           0.0
# 7499                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 0     debt consolidation  Short Term           99999999.0
# 1     debt consolidation   Long Term             264968.0
# 2     debt consolidation  Short Term           99999999.0
# 3     debt consolidation  Short Term             121396.0
# 4     debt consolidation  Short Term             125840.0
# ...                  ...         ...                  ...
# 7495               other  Short Term             129360.0
# 7496  debt consolidation   Long Term             444048.0
# 7497           buy a car  Short Term           99999999.0
# 7498  debt consolidation  Short Term             615274.0
# 7499  debt consolidation  Short Term              26928.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                    47386.0        7914.0         749.0               0
# 1                   394972.0       18373.0         737.0               1
# 2                   308389.0       13651.0         742.0               0
# 3                    95855.0       11338.0         694.0               0
# 4                    93309.0        7180.0         719.0               0
# ...                      ...           ...           ...             ...
# 7495                 73492.0        1900.0         697.0               0
# 7496                456399.0       12783.0        7410.0               1
# 7497                477812.0       12479.0         748.0               0
# 7498                476064.0       37118.0           NaN               0
# 7499                288192.0        9061.0           NaN               0
#
# [7500 rows x 17 columns]

# %% [markdown]
# **Описание датасета**
#
# * **Home Ownership** - домовладение
# * **Annual Income** - годовой доход
# * **Years in current job** - количество лет на текущем месте работы
# * **Tax Liens** - налоговые обременения
# * **Number of Open Accounts** - количество открытых счетов
# * **Years of Credit History** - количество лет кредитной истории
# * **Maximum Open Credit** - наибольший открытый кредит
# * **Number of Credit Problems** - количество проблем с кредитом
# * **Months since last delinquent** - количество месяцев с последней просрочки платежа
# * **Bankruptcies** - банкротства
# * **Purpose** - цель кредита
# * **Term** - срок кредита
# * **Current Loan Amount** - текущая сумма кредита
# * **Current Credit Balance** - текущий кредитный баланс
# * **Monthly Debt** - ежемесячный долг
# * **Credit Default** - факт невыполнения кредитных обязательств (0 - погашен вовремя, 1 - просрочка)

# %%
def view_matrix(df_train):
    
    '''показывает пропуски по колонкам и общую информацию о сете'''
    for colname in df_train.select_dtypes(include='object').columns:
        print(str(colname) + '\n\n' + str(df_train[colname].value_counts()) + '\n' + '*' * 100 + '\n')
    
    msno.matrix(df_train) 
    display("/usr/local/share/datasets/matrix_sorted.png")
    
    print(df_train.head())
    print(len(df_train) - df_train.count(), df_train.info())

# %%
view_matrix(df_train)
# Out:
# Home Ownership
#
# Home Mortgage    3637
# Rent             3204
# Own Home          647
# Have Mortgage      12
# Name: Home Ownership, dtype: int64
# ****************************************************************************************************
#
# Years in current job
#
# 10+ years    2332
# 2 years       705
# 3 years       620
# < 1 year      563
# 5 years       516
# 1 year        504
# 4 years       469
# 6 years       426
# 7 years       396
# 8 years       339
# 9 years       259
# Name: Years in current job, dtype: int64
# ****************************************************************************************************
#
# Purpose
#
# debt consolidation      5944
# other                    665
# home improvements        412
# business loan            129
# buy a car                 96
# medical bills             71
# major purchase            40
# take a trip               37
# buy house                 34
# small business            26
# wedding                   15
# moving                    11
# educational expenses      10
# vacation                   8
# renewable energy           2
# Name: Purpose, dtype: int64
# ****************************************************************************************************
#
# Term
#
# Short Term    5556
# Long Term     1944
# Name: Term, dtype: int64
# ****************************************************************************************************
# '/usr/local/share/datasets/matrix_sorted.png'
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0       Own Home       482087.0                  NaN        0.0
# 1       Own Home      1025487.0            10+ years        0.0
# 2  Home Mortgage       751412.0              8 years        0.0
# 3       Own Home       805068.0              6 years        0.0
# 4           Rent       776264.0              8 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                        1.0                           NaN           1.0
# 1                        0.0                           NaN           0.0
# 2                        0.0                           NaN           0.0
# 3                        1.0                           NaN           1.0
# 4                        1.0                           NaN           0.0
#
#               Purpose        Term  Current Loan Amount  \
# 0  debt consolidation  Short Term           99999999.0
# 1  debt consolidation   Long Term             264968.0
# 2  debt consolidation  Short Term           99999999.0
# 3  debt consolidation  Short Term             121396.0
# 4  debt consolidation  Short Term             125840.0
#
#    Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                 47386.0        7914.0         749.0               0
# 1                394972.0       18373.0         737.0               1
# 2                308389.0       13651.0         742.0               0
# 3                 95855.0       11338.0         694.0               0
# 4                 93309.0        7180.0         719.0               0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 17 columns):
# Home Ownership                  7500 non-null object
# Annual Income                   5943 non-null float64
# Years in current job            7129 non-null object
# Tax Liens                       7500 non-null float64
# Number of Open Accounts         7500 non-null float64
# Years of Credit History         7500 non-null float64
# Maximum Open Credit             7500 non-null float64
# Number of Credit Problems       7500 non-null float64
# Months since last delinquent    3419 non-null float64
# Bankruptcies                    7486 non-null float64
# Purpose                         7500 non-null object
# Term                            7500 non-null object
# Current Loan Amount             7500 non-null float64
# Current Credit Balance          7500 non-null float64
# Monthly Debt                    7500 non-null float64
# Credit Score                    5943 non-null float64
# Credit Default                  7500 non-null int64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 996.2+ KB
# Home Ownership                     0
# Annual Income                   1557
# Years in current job             371
# Tax Liens                          0
# Number of Open Accounts            0
# Years of Credit History            0
# Maximum Open Credit                0
# Number of Credit Problems          0
# Months since last delinquent    4081
# Bankruptcies                      14
# Purpose                            0
# Term                               0
# Current Loan Amount                0
# Current Credit Balance             0
# Monthly Debt                       0
# Credit Score                    1557
# Credit Default                     0
# dtype: int64 None

# %% [markdown]
# **Обработка датасета**
#
# Общий подход
# *  перевести объекты в нумерический вид присвоив им метки
# *  заполнить пропущенные значения

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def prepare_label(df_train):
    '''функция преобразующая строковые объекты в метки'''
    
    le = LabelEncoder()

    for col in df_train.columns:       
        if df_train[col].dtypes=='object':
            df_train[col]=le.fit_transform(df_train[col].astype(str))
    return df_train

# %%
prepare_label(df_train)
# Out:
#       Home Ownership  Annual Income  Years in current job  Tax Liens  \
# 0                  2       482087.0                    11        0.0
# 1                  2      1025487.0                     1        0.0
# 2                  1       751412.0                     8        0.0
# 3                  2       805068.0                     6        0.0
# 4                  3       776264.0                     8        0.0
# ...              ...            ...                   ...        ...
# 7495               3       402192.0                    10        0.0
# 7496               1      1533984.0                     0        0.0
# 7497               3      1878910.0                     6        0.0
# 7498               1            NaN                    11        0.0
# 7499               3            NaN                     4        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                     26.3             685960.0
# 1                        15.0                     15.3            1181730.0
# 2                        11.0                     35.0            1182434.0
# 3                         8.0                     22.5             147400.0
# 4                        13.0                     13.6             385836.0
# ...                       ...                      ...                  ...
# 7495                      3.0                      8.5             107866.0
# 7496                     10.0                     26.5             686312.0
# 7497                     12.0                     32.1            1778920.0
# 7498                     21.0                     26.5            1141250.0
# 7499                      8.0                      9.4             480832.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           1.0                           NaN           1.0
# 1                           0.0                           NaN           0.0
# 2                           0.0                           NaN           0.0
# 3                           1.0                           NaN           1.0
# 4                           1.0                           NaN           0.0
# ...                         ...                           ...           ...
# 7495                        0.0                           NaN           0.0
# 7496                        0.0                          43.0           0.0
# 7497                        0.0                           NaN           0.0
# 7498                        0.0                           NaN           0.0
# 7499                        0.0                           NaN           0.0
#
#       Purpose  Term  Current Loan Amount  Current Credit Balance  \
# 0           3     1           99999999.0                 47386.0
# 1           3     0             264968.0                394972.0
# 2           3     1           99999999.0                308389.0
# 3           3     1             121396.0                 95855.0
# 4           3     1             125840.0                 93309.0
# ...       ...   ...                  ...                     ...
# 7495        9     1             129360.0                 73492.0
# 7496        3     0             444048.0                456399.0
# 7497        1     1           99999999.0                477812.0
# 7498        3     1             615274.0                476064.0
# 7499        3     1              26928.0                288192.0
#
#       Monthly Debt  Credit Score  Credit Default
# 0           7914.0         749.0               0
# 1          18373.0         737.0               1
# 2          13651.0         742.0               0
# 3          11338.0         694.0               0
# 4           7180.0         719.0               0
# ...            ...           ...             ...
# 7495        1900.0         697.0               0
# 7496       12783.0        7410.0               1
# 7497       12479.0         748.0               0
# 7498       37118.0           NaN               0
# 7499        9061.0           NaN               0
#
# [7500 rows x 17 columns]

# %%
# библиотека для заполнения пропусков
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
def missing_imputer(df_train):
    '''функция заполняющая пробелы'''
    
    numeric_cols = df_train.select_dtypes(include=[np.number])

    imp_iter = IterativeImputer(n_nearest_features=4,max_iter=10, sample_posterior=True, random_state=123)
    df_train = imp_iter.fit_transform(numeric_cols)
 
    df_train = pd.DataFrame(df_train, columns=numeric_cols.columns)
    
    return df_train

# %%
df_train=missing_imputer(df_train)
df_train
# Out:
#       Home Ownership  Annual Income  Years in current job  Tax Liens  \
# 0                2.0   4.820870e+05                  11.0        0.0
# 1                2.0   1.025487e+06                   1.0        0.0
# 2                1.0   7.514120e+05                   8.0        0.0
# 3                2.0   8.050680e+05                   6.0        0.0
# 4                3.0   7.762640e+05                   8.0        0.0
# ...              ...            ...                   ...        ...
# 7495             3.0   4.021920e+05                  10.0        0.0
# 7496             1.0   1.533984e+06                   0.0        0.0
# 7497             3.0   1.878910e+06                   6.0        0.0
# 7498             1.0   2.832489e+06                  11.0        0.0
# 7499             3.0   1.000882e+06                   4.0        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                     26.3             685960.0
# 1                        15.0                     15.3            1181730.0
# 2                        11.0                     35.0            1182434.0
# 3                         8.0                     22.5             147400.0
# 4                        13.0                     13.6             385836.0
# ...                       ...                      ...                  ...
# 7495                      3.0                      8.5             107866.0
# 7496                     10.0                     26.5             686312.0
# 7497                     12.0                     32.1            1778920.0
# 7498                     21.0                     26.5            1141250.0
# 7499                      8.0                      9.4             480832.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           1.0                     39.842803           1.0
# 1                           0.0                     24.730240           0.0
# 2                           0.0                     20.013996           0.0
# 3                           1.0                     36.408613           1.0
# 4                           1.0                    -12.639178           0.0
# ...                         ...                           ...           ...
# 7495                        0.0                     31.707424           0.0
# 7496                        0.0                     43.000000           0.0
# 7497                        0.0                     34.880427           0.0
# 7498                        0.0                     33.853861           0.0
# 7499                        0.0                     37.459031           0.0
#
#       Purpose  Term  Current Loan Amount  Current Credit Balance  \
# 0         3.0   1.0           99999999.0                 47386.0
# 1         3.0   0.0             264968.0                394972.0
# 2         3.0   1.0           99999999.0                308389.0
# 3         3.0   1.0             121396.0                 95855.0
# 4         3.0   1.0             125840.0                 93309.0
# ...       ...   ...                  ...                     ...
# 7495      9.0   1.0             129360.0                 73492.0
# 7496      3.0   0.0             444048.0                456399.0
# 7497      1.0   1.0           99999999.0                477812.0
# 7498      3.0   1.0             615274.0                476064.0
# 7499      3.0   1.0              26928.0                288192.0
#
#       Monthly Debt  Credit Score  Credit Default
# 0           7914.0    749.000000             0.0
# 1          18373.0    737.000000             1.0
# 2          13651.0    742.000000             0.0
# 3          11338.0    694.000000             0.0
# 4           7180.0    719.000000             0.0
# ...            ...           ...             ...
# 7495        1900.0    697.000000             0.0
# 7496       12783.0   7410.000000             1.0
# 7497       12479.0    748.000000             0.0
# 7498       37118.0    914.955393             0.0
# 7499        9061.0   2031.879062             0.0
#
# [7500 rows x 17 columns]

# %%
def prepare_missing_n_label(df_train):
    
    ''' сборная функция присваивающая метки и обрабатывающая пропуски '''
    
    prepare_label(df_train)
    missing_imputer(df_train)
    
    return df_train

# %%
# Итоговый датасет
df_train=prepare_missing_n_label(df_train)

# %% [markdown]
# * Проверка обработанных данных

# %%
view_matrix(df_train)
# Out:
# '/usr/local/share/datasets/matrix_sorted.png'
#    Home Ownership  Annual Income  Years in current job  Tax Liens  \
# 0             2.0       482087.0                  11.0        0.0
# 1             2.0      1025487.0                   1.0        0.0
# 2             1.0       751412.0                   8.0        0.0
# 3             2.0       805068.0                   6.0        0.0
# 4             3.0       776264.0                   8.0        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                        1.0                     39.842803           1.0
# 1                        0.0                     24.730240           0.0
# 2                        0.0                     20.013996           0.0
# 3                        1.0                     36.408613           1.0
# 4                        1.0                    -12.639178           0.0
#
#    Purpose  Term  Current Loan Amount  Current Credit Balance  Monthly Debt  \
# 0      3.0   1.0           99999999.0                 47386.0        7914.0
# 1      3.0   0.0             264968.0                394972.0       18373.0
# 2      3.0   1.0           99999999.0                308389.0       13651.0
# 3      3.0   1.0             121396.0                 95855.0       11338.0
# 4      3.0   1.0             125840.0                 93309.0        7180.0
#
#    Credit Score  Credit Default
# 0         749.0             0.0
# 1         737.0             1.0
# 2         742.0             0.0
# 3         694.0             0.0
# 4         719.0             0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 17 columns):
# Home Ownership                  7500 non-null float64
# Annual Income                   7500 non-null float64
# Years in current job            7500 non-null float64
# Tax Liens                       7500 non-null float64
# Number of Open Accounts         7500 non-null float64
# Years of Credit History         7500 non-null float64
# Maximum Open Credit             7500 non-null float64
# Number of Credit Problems       7500 non-null float64
# Months since last delinquent    7500 non-null float64
# Bankruptcies                    7500 non-null float64
# Purpose                         7500 non-null float64
# Term                            7500 non-null float64
# Current Loan Amount             7500 non-null float64
# Current Credit Balance          7500 non-null float64
# Monthly Debt                    7500 non-null float64
# Credit Score                    7500 non-null float64
# Credit Default                  7500 non-null float64
# dtypes: float64(17)
# memory usage: 996.2 KB
# Home Ownership                  0
# Annual Income                   0
# Years in current job            0
# Tax Liens                       0
# Number of Open Accounts         0
# Years of Credit History         0
# Maximum Open Credit             0
# Number of Credit Problems       0
# Months since last delinquent    0
# Bankruptcies                    0
# Purpose                         0
# Term                            0
# Current Loan Amount             0
# Current Credit Balance          0
# Monthly Debt                    0
# Credit Score                    0
# Credit Default                  0
# dtype: int64 None

# %% [markdown]
# *Наши данные готовы к более подробному рассмотрению*

# %% [markdown]
# **Рассмотрим как данные связаны с нашим целевым значением**

# %%
TARGET_NAME = 'Credit Default'
BASE_FEATURE_NAMES = df_train.columns.drop(TARGET_NAME).tolist()

# %%
corr_with_target = df_train[BASE_FEATURE_NAMES + [TARGET_NAME]].corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %%
correlations_data = df_train.corr()[TARGET_NAME].sort_values()
correlations_data
# Out:
# Current Loan Amount            -0.226522
# Term                           -0.181487
# Annual Income                  -0.068526
# Years of Credit History        -0.020567
# Current Credit Balance         -0.019522
# Maximum Open Credit            -0.014275
# Months since last delinquent   -0.005930
# Bankruptcies                    0.001045
# Purpose                         0.005841
# Monthly Debt                    0.018480
# Number of Credit Problems       0.020088
# Years in current job            0.020398
# Tax Liens                       0.024368
# Number of Open Accounts         0.028884
# Home Ownership                  0.065620
# Credit Score                    0.337122
# Credit Default                  1.000000
# Name: Credit Default, dtype: float64

# %%
plt.figure(figsize = (25,20))

sns.set(font_scale=1.4)
sns.heatmap(df_train[BASE_FEATURE_NAMES].corr().round(3), annot=True, linewidths=.5, cmap='GnBu')

plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# **Рассмотрим характер распределения данных по целевому признаку**

# %%
for column in df_train:
    sns.jointplot(y=column, x= 'Credit Default', data=df_train)
    plt.show()

# %% [markdown]
# ## Подготовка модели<a class="anchor" id="make_model"></a>

# %%
def show_feature_importances(feature_names, feature_importances, get_top=None):
    feature_importances = pd.DataFrame({'feature': feature_names, 'importance': feature_importances})
    feature_importances = feature_importances.sort_values('importance', ascending=False)
       
    plt.figure(figsize = (20, len(feature_importances) * 0.355))
    
    sns.barplot(feature_importances['importance'], feature_importances['feature'])
    
    plt.xlabel('Importance')
    plt.title('Importance of features')
    plt.show()
    
    if get_top is not None:
        return feature_importances['feature'][:get_top].tolist()

# %%
def get_classification_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    print('TRAIN\n\n' + classification_report(y_train_true, y_train_pred))
    print('TEST\n\n' + classification_report(y_test_true, y_test_pred))
    print('CONFUSION MATRIX\n')
    print(pd.crosstab(y_test_true, y_test_pred))

# %%
def show_proba_calibration_plots(y_predicted_probs, y_true_labels):
    preds_with_true_labels = np.array(list(zip(y_predicted_probs, y_true_labels)))

    thresholds = []
    precisions = []
    recalls = []
    f1_scores = []

    for threshold in np.linspace(0.1, 0.9, 9):
        thresholds.append(threshold)
        precisions.append(precision_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))
        recalls.append(recall_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))
        f1_scores.append(f1_score(y_true_labels, list(map(int, y_predicted_probs > threshold))))

    scores_table = pd.DataFrame({'f1':f1_scores,
                                 'precision':precisions,
                                 'recall':recalls,
                                 'probability':thresholds}).sort_values('f1', ascending=False).round(3)
  
    figure = plt.figure(figsize = (15, 5))

    plt1 = figure.add_subplot(121)
    plt1.plot(thresholds, precisions, label='Precision', linewidth=4)
    plt1.plot(thresholds, recalls, label='Recall', linewidth=4)
    plt1.plot(thresholds, f1_scores, label='F1', linewidth=4)
    plt1.set_ylabel('Scores')
    plt1.set_xlabel('Probability threshold')
    plt1.set_title('Probabilities threshold calibration')
    plt1.legend(bbox_to_anchor=(0.25, 0.25))   
    plt1.table(cellText = scores_table.values,
               colLabels = scores_table.columns, 
               colLoc = 'center', cellLoc = 'center', loc = 'bottom', bbox = [0, -1.3, 1, 1])

    plt2 = figure.add_subplot(122)
    plt2.hist(preds_with_true_labels[preds_with_true_labels[:, 1] == 0][:, 0], 
              label='Another class', color='royalblue', alpha=1)
    plt2.hist(preds_with_true_labels[preds_with_true_labels[:, 1] == 1][:, 0], 
              label='Main class', color='darkcyan', alpha=0.8)
    plt2.set_ylabel('Number of examples')
    plt2.set_xlabel('Probabilities')
    plt2.set_title('Probability histogram')
    plt2.legend(bbox_to_anchor=(1, 1))

    plt.show()

# %% [markdown]
# **Предварительный отбор признаков**

# %%
FEATS_BASE = ['Home Ownership', 'Annual Income', 'Years in current job', 'Tax Liens',
       'Number of Open Accounts', 'Years of Credit History',
       'Maximum Open Credit', 'Number of Credit Problems',
       'Months since last delinquent', 'Bankruptcies', 'Purpose', 'Term',
       'Current Loan Amount', 'Current Credit Balance', 'Monthly Debt',
       'Credit Score']
TARGET_NAME = ['Credit Default']

# %%
X = df_train[FEATS_BASE]
y = df_train[TARGET_NAME]

# %% [markdown]
# * Предварительная модель

# %%
model= CatBoostClassifier()
model.fit(X, y)
# Out:
# Learning rate set to 0.024355
# 0:	learn: 0.6819824	total: 9.32ms	remaining: 9.31s
# 1:	learn: 0.6685523	total: 18.5ms	remaining: 9.25s
# 2:	learn: 0.6567809	total: 28.2ms	remaining: 9.36s
# 3:	learn: 0.6459795	total: 37.7ms	remaining: 9.38s
# 4:	learn: 0.6390133	total: 47.4ms	remaining: 9.43s
# 5:	learn: 0.6288776	total: 56.5ms	remaining: 9.36s
# 6:	learn: 0.6216759	total: 66.2ms	remaining: 9.39s
# 7:	learn: 0.6139734	total: 75.4ms	remaining: 9.36s
# 8:	learn: 0.6062864	total: 84.9ms	remaining: 9.35s
# 9:	learn: 0.5982000	total: 92.7ms	remaining: 9.18s
# 10:	learn: 0.5904322	total: 102ms	remaining: 9.18s
# 11:	learn: 0.5848824	total: 112ms	remaining: 9.19s
# 12:	learn: 0.5792802	total: 121ms	remaining: 9.18s
# 13:	learn: 0.5742003	total: 130ms	remaining: 9.18s
# 14:	learn: 0.5670337	total: 140ms	remaining: 9.18s
# 15:	learn: 0.5627105	total: 149ms	remaining: 9.16s
# 16:	learn: 0.5585041	total: 155ms	remaining: 8.97s
# 17:	learn: 0.5551144	total: 165ms	remaining: 8.98s
# 18:	learn: 0.5512837	total: 174ms	remaining: 8.99s
# 19:	learn: 0.5477764	total: 184ms	remaining: 9s
# 20:	learn: 0.5447031	total: 193ms	remaining: 9.01s
# 21:	learn: 0.5415292	total: 208ms	remaining: 9.24s
# 22:	learn: 0.5365227	total: 221ms	remaining: 9.38s
# 23:	learn: 0.5335197	total: 230ms	remaining: 9.37s
# 24:	learn: 0.5307918	total: 240ms	remaining: 9.36s
# 25:	learn: 0.5287997	total: 247ms	remaining: 9.27s
# 26:	learn: 0.5265446	total: 257ms	remaining: 9.25s
# 27:	learn: 0.5246115	total: 266ms	remaining: 9.23s
# 28:	learn: 0.5226690	total: 276ms	remaining: 9.23s
# 29:	learn: 0.5208345	total: 286ms	remaining: 9.24s
# 30:	learn: 0.5178995	total: 295ms	remaining: 9.23s
# 31:	learn: 0.5160283	total: 305ms	remaining: 9.22s
# 32:	learn: 0.5133107	total: 314ms	remaining: 9.21s
# 33:	learn: 0.5118147	total: 324ms	remaining: 9.22s
# 34:	learn: 0.5105177	total: 334ms	remaining: 9.2s
# 35:	learn: 0.5091432	total: 343ms	remaining: 9.19s
# 36:	learn: 0.5079262	total: 350ms	remaining: 9.1s
# 37:	learn: 0.5064867	total: 359ms	remaining: 9.09s
# 38:	learn: 0.5050690	total: 369ms	remaining: 9.09s
# 39:	learn: 0.5037869	total: 378ms	remaining: 9.08s
# 40:	learn: 0.5023561	total: 388ms	remaining: 9.07s
# 41:	learn: 0.5010470	total: 397ms	remaining: 9.07s
# 42:	learn: 0.4999926	total: 416ms	remaining: 9.27s
# 43:	learn: 0.4986524	total: 431ms	remaining: 9.36s
# 44:	learn: 0.4977046	total: 441ms	remaining: 9.35s
# 45:	learn: 0.4967243	total: 450ms	remaining: 9.33s
# 46:	learn: 0.4959223	total: 460ms	remaining: 9.32s
# 47:	learn: 0.4938999	total: 469ms	remaining: 9.3s
# 48:	learn: 0.4929966	total: 479ms	remaining: 9.29s
# 49:	learn: 0.4919370	total: 488ms	remaining: 9.28s
# 50:	learn: 0.4904966	total: 498ms	remaining: 9.27s
# 51:	learn: 0.4894750	total: 508ms	remaining: 9.25s
# 52:	learn: 0.4887725	total: 517ms	remaining: 9.24s
# 53:	learn: 0.4879455	total: 527ms	remaining: 9.23s
# 54:	learn: 0.4869420	total: 536ms	remaining: 9.21s
# 55:	learn: 0.4861389	total: 546ms	remaining: 9.2s
# 56:	learn: 0.4854859	total: 555ms	remaining: 9.19s
# 57:	learn: 0.4849743	total: 565ms	remaining: 9.18s
# 58:	learn: 0.4845116	total: 574ms	remaining: 9.16s
# 59:	learn: 0.4830179	total: 584ms	remaining: 9.14s
# 60:	learn: 0.4825916	total: 593ms	remaining: 9.13s
# 61:	learn: 0.4822238	total: 603ms	remaining: 9.12s
# 62:	learn: 0.4817207	total: 614ms	remaining: 9.13s
# 63:	learn: 0.4811537	total: 628ms	remaining: 9.19s
# 64:	learn: 0.4806200	total: 642ms	remaining: 9.23s
# 65:	learn: 0.4797886	total: 651ms	remaining: 9.22s
# 66:	learn: 0.4791150	total: 661ms	remaining: 9.21s
# 67:	learn: 0.4785489	total: 671ms	remaining: 9.2s
# 68:	learn: 0.4780621	total: 681ms	remaining: 9.18s
# 69:	learn: 0.4774494	total: 690ms	remaining: 9.17s
# 70:	learn: 0.4771211	total: 699ms	remaining: 9.15s
# 71:	learn: 0.4764243	total: 709ms	remaining: 9.14s
# 72:	learn: 0.4759112	total: 719ms	remaining: 9.13s
# 73:	learn: 0.4754965	total: 728ms	remaining: 9.11s
# 74:	learn: 0.4743957	total: 738ms	remaining: 9.1s
# 75:	learn: 0.4736228	total: 745ms	remaining: 9.06s
# 76:	learn: 0.4728662	total: 758ms	remaining: 9.08s
# 77:	learn: 0.4725563	total: 767ms	remaining: 9.07s
# 78:	learn: 0.4720680	total: 777ms	remaining: 9.05s
# 79:	learn: 0.4716389	total: 786ms	remaining: 9.04s
# 80:	learn: 0.4713168	total: 796ms	remaining: 9.03s
# 81:	learn: 0.4710182	total: 805ms	remaining: 9.01s
# 82:	learn: 0.4707056	total: 815ms	remaining: 9s
# 83:	learn: 0.4703480	total: 829ms	remaining: 9.04s
# 84:	learn: 0.4699901	total: 841ms	remaining: 9.05s
# 85:	learn: 0.4695547	total: 852ms	remaining: 9.05s
# 86:	learn: 0.4690723	total: 865ms	remaining: 9.08s
# 87:	learn: 0.4685869	total: 877ms	remaining: 9.09s
# 88:	learn: 0.4682396	total: 887ms	remaining: 9.08s
# 89:	learn: 0.4679756	total: 897ms	remaining: 9.07s
# 90:	learn: 0.4676867	total: 906ms	remaining: 9.05s
# 91:	learn: 0.4673618	total: 916ms	remaining: 9.04s
# 92:	learn: 0.4670579	total: 926ms	remaining: 9.03s
# 93:	learn: 0.4668517	total: 936ms	remaining: 9.03s
# 94:	learn: 0.4663339	total: 946ms	remaining: 9.01s
# 95:	learn: 0.4660416	total: 956ms	remaining: 9s
# 96:	learn: 0.4657323	total: 966ms	remaining: 8.99s
# 97:	learn: 0.4654139	total: 975ms	remaining: 8.98s
# 98:	learn: 0.4650345	total: 985ms	remaining: 8.96s
# 99:	learn: 0.4647443	total: 994ms	remaining: 8.95s
# 100:	learn: 0.4643279	total: 1s	remaining: 8.93s
# 101:	learn: 0.4640141	total: 1.01s	remaining: 8.92s
# 102:	learn: 0.4636525	total: 1.02s	remaining: 8.91s
# 103:	learn: 0.4634027	total: 1.04s	remaining: 8.99s
# 104:	learn: 0.4630845	total: 1.06s	remaining: 9.05s
# 105:	learn: 0.4627523	total: 1.07s	remaining: 9.05s
# 106:	learn: 0.4624780	total: 1.08s	remaining: 9.04s
# 107:	learn: 0.4621005	total: 1.09s	remaining: 9.02s
# 108:	learn: 0.4616981	total: 1.1s	remaining: 9.01s
# 109:	learn: 0.4615275	total: 1.11s	remaining: 8.99s
# 110:	learn: 0.4613212	total: 1.12s	remaining: 8.97s
# 111:	learn: 0.4609870	total: 1.13s	remaining: 8.96s
# 112:	learn: 0.4607990	total: 1.14s	remaining: 8.95s
# 113:	learn: 0.4605560	total: 1.15s	remaining: 8.93s
# 114:	learn: 0.4603548	total: 1.16s	remaining: 8.91s
# 115:	learn: 0.4600474	total: 1.17s	remaining: 8.9s
# 116:	learn: 0.4598399	total: 1.18s	remaining: 8.89s
# 117:	learn: 0.4596671	total: 1.19s	remaining: 8.88s
# 118:	learn: 0.4594166	total: 1.2s	remaining: 8.86s
# 119:	learn: 0.4591955	total: 1.21s	remaining: 8.85s
# 120:	learn: 0.4588876	total: 1.22s	remaining: 8.83s
# 121:	learn: 0.4583447	total: 1.22s	remaining: 8.8s
# 122:	learn: 0.4580971	total: 1.23s	remaining: 8.79s
# 123:	learn: 0.4578036	total: 1.24s	remaining: 8.78s
# 124:	learn: 0.4575576	total: 1.26s	remaining: 8.79s
# 125:	learn: 0.4572987	total: 1.27s	remaining: 8.83s
# 126:	learn: 0.4570504	total: 1.28s	remaining: 8.82s
# 127:	learn: 0.4568660	total: 1.29s	remaining: 8.81s
# 128:	learn: 0.4566274	total: 1.31s	remaining: 8.83s
# 129:	learn: 0.4564033	total: 1.32s	remaining: 8.81s
# 130:	learn: 0.4561314	total: 1.33s	remaining: 8.8s
# 131:	learn: 0.4559522	total: 1.34s	remaining: 8.79s
# 132:	learn: 0.4557603	total: 1.35s	remaining: 8.78s
# 133:	learn: 0.4554516	total: 1.36s	remaining: 8.77s
# 134:	learn: 0.4551761	total: 1.37s	remaining: 8.75s
# 135:	learn: 0.4549729	total: 1.38s	remaining: 8.74s
# 136:	learn: 0.4548433	total: 1.39s	remaining: 8.73s
# 137:	learn: 0.4546157	total: 1.39s	remaining: 8.71s
# 138:	learn: 0.4542725	total: 1.4s	remaining: 8.7s
# 139:	learn: 0.4540576	total: 1.41s	remaining: 8.68s
# 140:	learn: 0.4538684	total: 1.42s	remaining: 8.67s
# 141:	learn: 0.4533540	total: 1.43s	remaining: 8.65s
# 142:	learn: 0.4531570	total: 1.44s	remaining: 8.64s
# 143:	learn: 0.4528321	total: 1.45s	remaining: 8.64s
# 144:	learn: 0.4526101	total: 1.47s	remaining: 8.65s
# 145:	learn: 0.4524227	total: 1.48s	remaining: 8.64s
# 146:	learn: 0.4521600	total: 1.49s	remaining: 8.63s
# 147:	learn: 0.4519609	total: 1.5s	remaining: 8.62s
# 148:	learn: 0.4517089	total: 1.51s	remaining: 8.61s
# 149:	learn: 0.4515131	total: 1.52s	remaining: 8.59s
# 150:	learn: 0.4513822	total: 1.52s	remaining: 8.58s
# 151:	learn: 0.4512178	total: 1.53s	remaining: 8.56s
# 152:	learn: 0.4509874	total: 1.54s	remaining: 8.55s
# 153:	learn: 0.4507493	total: 1.55s	remaining: 8.54s
# 154:	learn: 0.4504217	total: 1.56s	remaining: 8.53s
# 155:	learn: 0.4501536	total: 1.57s	remaining: 8.51s
# 156:	learn: 0.4499602	total: 1.58s	remaining: 8.51s
# 157:	learn: 0.4497626	total: 1.6s	remaining: 8.51s
# 158:	learn: 0.4495822	total: 1.61s	remaining: 8.49s
# 159:	learn: 0.4493518	total: 1.61s	remaining: 8.48s
# 160:	learn: 0.4492517	total: 1.63s	remaining: 8.47s
# 161:	learn: 0.4490368	total: 1.63s	remaining: 8.46s
# 162:	learn: 0.4488109	total: 1.65s	remaining: 8.48s
# 163:	learn: 0.4486166	total: 1.67s	remaining: 8.49s
# 164:	learn: 0.4484546	total: 1.68s	remaining: 8.48s
# 165:	learn: 0.4482258	total: 1.69s	remaining: 8.47s
# 166:	learn: 0.4481227	total: 1.7s	remaining: 8.46s
# 167:	learn: 0.4479582	total: 1.71s	remaining: 8.45s
# 168:	learn: 0.4477079	total: 1.72s	remaining: 8.43s
# 169:	learn: 0.4474857	total: 1.72s	remaining: 8.42s
# 170:	learn: 0.4472883	total: 1.73s	remaining: 8.41s
# 171:	learn: 0.4470880	total: 1.74s	remaining: 8.39s
# 172:	learn: 0.4468606	total: 1.75s	remaining: 8.38s
# 173:	learn: 0.4466410	total: 1.76s	remaining: 8.37s
# 174:	learn: 0.4464243	total: 1.77s	remaining: 8.35s
# 175:	learn: 0.4462513	total: 1.78s	remaining: 8.34s
# 176:	learn: 0.4460277	total: 1.79s	remaining: 8.33s
# 177:	learn: 0.4458119	total: 1.8s	remaining: 8.32s
# 178:	learn: 0.4456412	total: 1.81s	remaining: 8.3s
# 179:	learn: 0.4455125	total: 1.82s	remaining: 8.29s
# 180:	learn: 0.4453219	total: 1.83s	remaining: 8.28s
# 181:	learn: 0.4451732	total: 1.84s	remaining: 8.27s
# 182:	learn: 0.4446473	total: 1.85s	remaining: 8.25s
# 183:	learn: 0.4445084	total: 1.86s	remaining: 8.25s
# 184:	learn: 0.4442289	total: 1.87s	remaining: 8.25s
# 185:	learn: 0.4440082	total: 1.88s	remaining: 8.24s
# 186:	learn: 0.4438946	total: 1.89s	remaining: 8.23s
# 187:	learn: 0.4436941	total: 1.9s	remaining: 8.21s
# 188:	learn: 0.4434545	total: 1.91s	remaining: 8.2s
# 189:	learn: 0.4433459	total: 1.92s	remaining: 8.19s
# 190:	learn: 0.4432009	total: 1.93s	remaining: 8.17s
# 191:	learn: 0.4430554	total: 1.94s	remaining: 8.16s
# 192:	learn: 0.4429324	total: 1.95s	remaining: 8.15s
# 193:	learn: 0.4427795	total: 1.96s	remaining: 8.13s
# 194:	learn: 0.4426179	total: 1.97s	remaining: 8.12s
# 195:	learn: 0.4424706	total: 1.98s	remaining: 8.11s
# 196:	learn: 0.4423689	total: 1.99s	remaining: 8.1s
# 197:	learn: 0.4421524	total: 2s	remaining: 8.08s
# 198:	learn: 0.4419212	total: 2s	remaining: 8.07s
# 199:	learn: 0.4416920	total: 2.01s	remaining: 8.06s
# 200:	learn: 0.4414553	total: 2.02s	remaining: 8.05s
# 201:	learn: 0.4412861	total: 2.03s	remaining: 8.04s
# 202:	learn: 0.4411148	total: 2.04s	remaining: 8.02s
# 203:	learn: 0.4408072	total: 2.06s	remaining: 8.06s
# 204:	learn: 0.4406121	total: 2.08s	remaining: 8.05s
# 205:	learn: 0.4403341	total: 2.08s	remaining: 8.04s
# 206:	learn: 0.4400487	total: 2.1s	remaining: 8.03s
# 207:	learn: 0.4398725	total: 2.1s	remaining: 8.01s
# 208:	learn: 0.4396868	total: 2.11s	remaining: 8s
# 209:	learn: 0.4395234	total: 2.12s	remaining: 7.99s
# 210:	learn: 0.4392492	total: 2.13s	remaining: 7.98s
# 211:	learn: 0.4390779	total: 2.14s	remaining: 7.97s
# 212:	learn: 0.4388717	total: 2.15s	remaining: 7.96s
# 213:	learn: 0.4387006	total: 2.16s	remaining: 7.94s
# 214:	learn: 0.4384890	total: 2.17s	remaining: 7.93s
# 215:	learn: 0.4382779	total: 2.18s	remaining: 7.92s
# 216:	learn: 0.4380785	total: 2.19s	remaining: 7.91s
# 217:	learn: 0.4378949	total: 2.2s	remaining: 7.89s
# 218:	learn: 0.4377022	total: 2.21s	remaining: 7.89s
# 219:	learn: 0.4376193	total: 2.22s	remaining: 7.88s
# 220:	learn: 0.4374783	total: 2.23s	remaining: 7.88s
# 221:	learn: 0.4373116	total: 2.24s	remaining: 7.86s
# 222:	learn: 0.4371721	total: 2.25s	remaining: 7.85s
# 223:	learn: 0.4369927	total: 2.27s	remaining: 7.86s
# 224:	learn: 0.4368372	total: 2.28s	remaining: 7.86s
# 225:	learn: 0.4365777	total: 2.29s	remaining: 7.85s
# 226:	learn: 0.4363772	total: 2.3s	remaining: 7.84s
# 227:	learn: 0.4362193	total: 2.31s	remaining: 7.83s
# 228:	learn: 0.4360872	total: 2.32s	remaining: 7.81s
# 229:	learn: 0.4359310	total: 2.33s	remaining: 7.8s
# 230:	learn: 0.4357644	total: 2.34s	remaining: 7.79s
# 231:	learn: 0.4355739	total: 2.35s	remaining: 7.78s
# 232:	learn: 0.4354526	total: 2.36s	remaining: 7.76s
# 233:	learn: 0.4353073	total: 2.37s	remaining: 7.75s
# 234:	learn: 0.4350163	total: 2.38s	remaining: 7.74s
# 235:	learn: 0.4348744	total: 2.39s	remaining: 7.73s
# 236:	learn: 0.4346937	total: 2.4s	remaining: 7.71s
# 237:	learn: 0.4345160	total: 2.4s	remaining: 7.7s
# 238:	learn: 0.4342340	total: 2.42s	remaining: 7.69s
# 239:	learn: 0.4340445	total: 2.42s	remaining: 7.68s
# 240:	learn: 0.4338453	total: 2.43s	remaining: 7.67s
# 241:	learn: 0.4336970	total: 2.44s	remaining: 7.66s
# 242:	learn: 0.4335166	total: 2.45s	remaining: 7.64s
# 243:	learn: 0.4333670	total: 2.46s	remaining: 7.63s
# 244:	learn: 0.4332437	total: 2.48s	remaining: 7.63s
# 245:	learn: 0.4330132	total: 2.49s	remaining: 7.63s
# 246:	learn: 0.4328800	total: 2.5s	remaining: 7.62s
# 247:	learn: 0.4326767	total: 2.51s	remaining: 7.61s
# 248:	learn: 0.4324953	total: 2.52s	remaining: 7.6s
# 249:	learn: 0.4323033	total: 2.53s	remaining: 7.58s
# 250:	learn: 0.4321035	total: 2.54s	remaining: 7.57s
# 251:	learn: 0.4319112	total: 2.55s	remaining: 7.56s
# 252:	learn: 0.4317853	total: 2.56s	remaining: 7.55s
# 253:	learn: 0.4316775	total: 2.57s	remaining: 7.54s
# 254:	learn: 0.4313448	total: 2.58s	remaining: 7.53s
# 255:	learn: 0.4312522	total: 2.58s	remaining: 7.51s
# 256:	learn: 0.4309938	total: 2.59s	remaining: 7.5s
# 257:	learn: 0.4308001	total: 2.6s	remaining: 7.49s
# 258:	learn: 0.4306854	total: 2.61s	remaining: 7.48s
# 259:	learn: 0.4305712	total: 2.62s	remaining: 7.46s
# 260:	learn: 0.4303634	total: 2.63s	remaining: 7.45s
# 261:	learn: 0.4302877	total: 2.64s	remaining: 7.44s
# 262:	learn: 0.4301829	total: 2.65s	remaining: 7.43s
# 263:	learn: 0.4300011	total: 2.66s	remaining: 7.42s
# 264:	learn: 0.4298678	total: 2.67s	remaining: 7.41s
# 265:	learn: 0.4297433	total: 2.69s	remaining: 7.44s
# 266:	learn: 0.4295523	total: 2.7s	remaining: 7.42s
# 267:	learn: 0.4294788	total: 2.71s	remaining: 7.41s
# 268:	learn: 0.4293583	total: 2.72s	remaining: 7.4s
# 269:	learn: 0.4290985	total: 2.73s	remaining: 7.39s
# 270:	learn: 0.4289642	total: 2.74s	remaining: 7.38s
# 271:	learn: 0.4288316	total: 2.75s	remaining: 7.37s
# 272:	learn: 0.4286150	total: 2.76s	remaining: 7.36s
# 273:	learn: 0.4284988	total: 2.77s	remaining: 7.34s
# 274:	learn: 0.4283398	total: 2.78s	remaining: 7.33s
# 275:	learn: 0.4281171	total: 2.79s	remaining: 7.32s
# 276:	learn: 0.4278159	total: 2.8s	remaining: 7.31s
# 277:	learn: 0.4275545	total: 2.81s	remaining: 7.3s
# 278:	learn: 0.4274574	total: 2.82s	remaining: 7.29s
# 279:	learn: 0.4273859	total: 2.83s	remaining: 7.27s
# 280:	learn: 0.4272287	total: 2.84s	remaining: 7.26s
# 281:	learn: 0.4270550	total: 2.85s	remaining: 7.25s
# 282:	learn: 0.4269021	total: 2.86s	remaining: 7.24s
# 283:	learn: 0.4268191	total: 2.87s	remaining: 7.23s
# 284:	learn: 0.4267345	total: 2.88s	remaining: 7.21s
# 285:	learn: 0.4264761	total: 2.88s	remaining: 7.2s
# 286:	learn: 0.4263724	total: 2.9s	remaining: 7.19s
# 287:	learn: 0.4261762	total: 2.91s	remaining: 7.19s
# 288:	learn: 0.4260071	total: 2.92s	remaining: 7.18s
# 289:	learn: 0.4258629	total: 2.93s	remaining: 7.17s
# 290:	learn: 0.4257299	total: 2.94s	remaining: 7.16s
# 291:	learn: 0.4256115	total: 2.95s	remaining: 7.15s
# 292:	learn: 0.4254168	total: 2.96s	remaining: 7.14s
# 293:	learn: 0.4252145	total: 2.97s	remaining: 7.13s
# 294:	learn: 0.4250152	total: 2.98s	remaining: 7.12s
# 295:	learn: 0.4248834	total: 2.99s	remaining: 7.11s
# 296:	learn: 0.4247309	total: 3s	remaining: 7.09s
# 297:	learn: 0.4246265	total: 3.01s	remaining: 7.08s
# 298:	learn: 0.4245321	total: 3.02s	remaining: 7.07s
# 299:	learn: 0.4243488	total: 3.02s	remaining: 7.06s
# 300:	learn: 0.4242033	total: 3.03s	remaining: 7.05s
# 301:	learn: 0.4239919	total: 3.04s	remaining: 7.04s
# 302:	learn: 0.4238808	total: 3.05s	remaining: 7.03s
# 303:	learn: 0.4237915	total: 3.06s	remaining: 7.01s
# 304:	learn: 0.4236463	total: 3.07s	remaining: 7s
# 305:	learn: 0.4233656	total: 3.08s	remaining: 6.99s
# 306:	learn: 0.4231797	total: 3.09s	remaining: 6.98s
# 307:	learn: 0.4231082	total: 3.11s	remaining: 6.98s
# 308:	learn: 0.4229987	total: 3.12s	remaining: 6.98s
# 309:	learn: 0.4228594	total: 3.13s	remaining: 6.97s
# 310:	learn: 0.4226892	total: 3.14s	remaining: 6.96s
# 311:	learn: 0.4225033	total: 3.15s	remaining: 6.94s
# 312:	learn: 0.4223139	total: 3.16s	remaining: 6.93s
# 313:	learn: 0.4221385	total: 3.17s	remaining: 6.92s
# 314:	learn: 0.4220212	total: 3.18s	remaining: 6.91s
# 315:	learn: 0.4219161	total: 3.19s	remaining: 6.9s
# 316:	learn: 0.4217979	total: 3.2s	remaining: 6.89s
# 317:	learn: 0.4215721	total: 3.21s	remaining: 6.88s
# 318:	learn: 0.4213481	total: 3.22s	remaining: 6.87s
# 319:	learn: 0.4211688	total: 3.23s	remaining: 6.86s
# 320:	learn: 0.4210877	total: 3.24s	remaining: 6.84s
# 321:	learn: 0.4209895	total: 3.25s	remaining: 6.83s
# 322:	learn: 0.4208837	total: 3.25s	remaining: 6.82s
# 323:	learn: 0.4206321	total: 3.27s	remaining: 6.81s
# 324:	learn: 0.4203802	total: 3.27s	remaining: 6.8s
# 325:	learn: 0.4202402	total: 3.28s	remaining: 6.79s
# 326:	learn: 0.4199815	total: 3.29s	remaining: 6.78s
# 327:	learn: 0.4198732	total: 3.3s	remaining: 6.77s
# 328:	learn: 0.4197119	total: 3.32s	remaining: 6.77s
# 329:	learn: 0.4195384	total: 3.33s	remaining: 6.76s
# 330:	learn: 0.4193327	total: 3.34s	remaining: 6.75s
# 331:	learn: 0.4191664	total: 3.35s	remaining: 6.74s
# 332:	learn: 0.4190601	total: 3.36s	remaining: 6.73s
# 333:	learn: 0.4188932	total: 3.37s	remaining: 6.72s
# 334:	learn: 0.4187081	total: 3.38s	remaining: 6.71s
# 335:	learn: 0.4185340	total: 3.39s	remaining: 6.7s
# 336:	learn: 0.4184293	total: 3.4s	remaining: 6.68s
# 337:	learn: 0.4182437	total: 3.41s	remaining: 6.67s
# 338:	learn: 0.4180510	total: 3.42s	remaining: 6.66s
# 339:	learn: 0.4178714	total: 3.43s	remaining: 6.65s
# 340:	learn: 0.4178053	total: 3.44s	remaining: 6.64s
# 341:	learn: 0.4176132	total: 3.44s	remaining: 6.63s
# 342:	learn: 0.4173968	total: 3.46s	remaining: 6.62s
# 343:	learn: 0.4172044	total: 3.46s	remaining: 6.61s
# 344:	learn: 0.4170711	total: 3.47s	remaining: 6.59s
# 345:	learn: 0.4168486	total: 3.48s	remaining: 6.58s
# 346:	learn: 0.4166817	total: 3.49s	remaining: 6.57s
# 347:	learn: 0.4165092	total: 3.5s	remaining: 6.56s
# 348:	learn: 0.4163552	total: 3.52s	remaining: 6.56s
# 349:	learn: 0.4162352	total: 3.53s	remaining: 6.56s
# 350:	learn: 0.4160574	total: 3.54s	remaining: 6.54s
# 351:	learn: 0.4158154	total: 3.55s	remaining: 6.53s
# 352:	learn: 0.4156811	total: 3.56s	remaining: 6.52s
# 353:	learn: 0.4154421	total: 3.57s	remaining: 6.51s
# 354:	learn: 0.4152893	total: 3.58s	remaining: 6.5s
# 355:	learn: 0.4151201	total: 3.59s	remaining: 6.49s
# 356:	learn: 0.4149817	total: 3.6s	remaining: 6.48s
# 357:	learn: 0.4148779	total: 3.61s	remaining: 6.47s
# 358:	learn: 0.4146613	total: 3.62s	remaining: 6.46s
# 359:	learn: 0.4144453	total: 3.63s	remaining: 6.45s
# 360:	learn: 0.4142839	total: 3.63s	remaining: 6.43s
# 361:	learn: 0.4141005	total: 3.65s	remaining: 6.42s
# 362:	learn: 0.4139378	total: 3.65s	remaining: 6.41s
# 363:	learn: 0.4137584	total: 3.66s	remaining: 6.4s
# 364:	learn: 0.4136069	total: 3.67s	remaining: 6.39s
# 365:	learn: 0.4134435	total: 3.68s	remaining: 6.38s
# 366:	learn: 0.4132152	total: 3.69s	remaining: 6.37s
# 367:	learn: 0.4130274	total: 3.7s	remaining: 6.36s
# 368:	learn: 0.4128984	total: 3.71s	remaining: 6.35s
# 369:	learn: 0.4127686	total: 3.73s	remaining: 6.34s
# 370:	learn: 0.4126461	total: 3.74s	remaining: 6.34s
# 371:	learn: 0.4124393	total: 3.75s	remaining: 6.33s
# 372:	learn: 0.4123337	total: 3.76s	remaining: 6.32s
# 373:	learn: 0.4121368	total: 3.77s	remaining: 6.3s
# 374:	learn: 0.4119132	total: 3.78s	remaining: 6.29s
# 375:	learn: 0.4117814	total: 3.79s	remaining: 6.28s
# 376:	learn: 0.4116946	total: 3.79s	remaining: 6.27s
# 377:	learn: 0.4114964	total: 3.8s	remaining: 6.26s
# 378:	learn: 0.4113450	total: 3.81s	remaining: 6.25s
# 379:	learn: 0.4112591	total: 3.82s	remaining: 6.24s
# 380:	learn: 0.4111149	total: 3.83s	remaining: 6.23s
# 381:	learn: 0.4110438	total: 3.84s	remaining: 6.22s
# 382:	learn: 0.4109345	total: 3.85s	remaining: 6.2s
# 383:	learn: 0.4107748	total: 3.86s	remaining: 6.19s
# 384:	learn: 0.4105213	total: 3.87s	remaining: 6.18s
# 385:	learn: 0.4103955	total: 3.88s	remaining: 6.17s
# 386:	learn: 0.4102405	total: 3.89s	remaining: 6.16s
# 387:	learn: 0.4099765	total: 3.9s	remaining: 6.15s
# 388:	learn: 0.4096909	total: 3.91s	remaining: 6.14s
# 389:	learn: 0.4095405	total: 3.92s	remaining: 6.13s
# 390:	learn: 0.4094150	total: 3.93s	remaining: 6.13s
# 391:	learn: 0.4092189	total: 3.95s	remaining: 6.12s
# 392:	learn: 0.4090295	total: 3.96s	remaining: 6.11s
# 393:	learn: 0.4088675	total: 3.97s	remaining: 6.1s
# 394:	learn: 0.4086553	total: 3.98s	remaining: 6.09s
# 395:	learn: 0.4085005	total: 3.99s	remaining: 6.08s
# 396:	learn: 0.4084014	total: 4s	remaining: 6.07s
# 397:	learn: 0.4082806	total: 4.01s	remaining: 6.06s
# 398:	learn: 0.4081148	total: 4.01s	remaining: 6.05s
# 399:	learn: 0.4078796	total: 4.02s	remaining: 6.04s
# 400:	learn: 0.4076306	total: 4.03s	remaining: 6.03s
# 401:	learn: 0.4073401	total: 4.04s	remaining: 6.01s
# 402:	learn: 0.4071793	total: 4.05s	remaining: 6s
# 403:	learn: 0.4070327	total: 4.06s	remaining: 5.99s
# 404:	learn: 0.4068896	total: 4.07s	remaining: 5.98s
# 405:	learn: 0.4067066	total: 4.08s	remaining: 5.97s
# 406:	learn: 0.4065756	total: 4.09s	remaining: 5.96s
# 407:	learn: 0.4064239	total: 4.1s	remaining: 5.95s
# 408:	learn: 0.4062394	total: 4.11s	remaining: 5.94s
# 409:	learn: 0.4060824	total: 4.12s	remaining: 5.93s
# 410:	learn: 0.4059796	total: 4.13s	remaining: 5.92s
# 411:	learn: 0.4058283	total: 4.14s	remaining: 5.91s
# 412:	learn: 0.4056715	total: 4.15s	remaining: 5.91s
# 413:	learn: 0.4054460	total: 4.16s	remaining: 5.89s
# 414:	learn: 0.4052184	total: 4.17s	remaining: 5.88s
# 415:	learn: 0.4050723	total: 4.19s	remaining: 5.88s
# 416:	learn: 0.4047967	total: 4.2s	remaining: 5.87s
# 417:	learn: 0.4046664	total: 4.21s	remaining: 5.86s
# 418:	learn: 0.4044306	total: 4.21s	remaining: 5.84s
# 419:	learn: 0.4042623	total: 4.22s	remaining: 5.83s
# 420:	learn: 0.4040973	total: 4.23s	remaining: 5.82s
# 421:	learn: 0.4039521	total: 4.24s	remaining: 5.81s
# 422:	learn: 0.4037760	total: 4.25s	remaining: 5.8s
# 423:	learn: 0.4036570	total: 4.26s	remaining: 5.79s
# 424:	learn: 0.4035300	total: 4.27s	remaining: 5.78s
# 425:	learn: 0.4033628	total: 4.28s	remaining: 5.77s
# 426:	learn: 0.4031800	total: 4.29s	remaining: 5.76s
# 427:	learn: 0.4030015	total: 4.3s	remaining: 5.75s
# 428:	learn: 0.4028488	total: 4.31s	remaining: 5.74s
# 429:	learn: 0.4026794	total: 4.32s	remaining: 5.72s
# 430:	learn: 0.4025421	total: 4.33s	remaining: 5.71s
# 431:	learn: 0.4023672	total: 4.34s	remaining: 5.7s
# 432:	learn: 0.4022438	total: 4.35s	remaining: 5.7s
# 433:	learn: 0.4019861	total: 4.36s	remaining: 5.69s
# 434:	learn: 0.4017760	total: 4.37s	remaining: 5.68s
# 435:	learn: 0.4015567	total: 4.38s	remaining: 5.67s
# 436:	learn: 0.4014307	total: 4.39s	remaining: 5.66s
# 437:	learn: 0.4012676	total: 4.4s	remaining: 5.65s
# 438:	learn: 0.4010984	total: 4.41s	remaining: 5.64s
# 439:	learn: 0.4009082	total: 4.42s	remaining: 5.63s
# 440:	learn: 0.4006567	total: 4.43s	remaining: 5.62s
# 441:	learn: 0.4004966	total: 4.44s	remaining: 5.61s
# 442:	learn: 0.4002763	total: 4.45s	remaining: 5.59s
# 443:	learn: 0.4000710	total: 4.46s	remaining: 5.58s
# 444:	learn: 0.3998893	total: 4.47s	remaining: 5.57s
# 445:	learn: 0.3996826	total: 4.48s	remaining: 5.56s
# 446:	learn: 0.3995085	total: 4.49s	remaining: 5.55s
# 447:	learn: 0.3993464	total: 4.5s	remaining: 5.54s
# 448:	learn: 0.3990619	total: 4.51s	remaining: 5.53s
# 449:	learn: 0.3989122	total: 4.52s	remaining: 5.52s
# 450:	learn: 0.3987794	total: 4.53s	remaining: 5.51s
# 451:	learn: 0.3986085	total: 4.53s	remaining: 5.5s
# 452:	learn: 0.3984304	total: 4.54s	remaining: 5.49s
# 453:	learn: 0.3983092	total: 4.57s	remaining: 5.49s
# 454:	learn: 0.3981121	total: 4.58s	remaining: 5.48s
# 455:	learn: 0.3980010	total: 4.59s	remaining: 5.47s
# 456:	learn: 0.3978733	total: 4.6s	remaining: 5.46s
# 457:	learn: 0.3977326	total: 4.61s	remaining: 5.45s
# 458:	learn: 0.3975483	total: 4.62s	remaining: 5.44s
# 459:	learn: 0.3973410	total: 4.63s	remaining: 5.43s
# 460:	learn: 0.3971983	total: 4.63s	remaining: 5.42s
# 461:	learn: 0.3969610	total: 4.64s	remaining: 5.41s
# 462:	learn: 0.3968081	total: 4.65s	remaining: 5.4s
# 463:	learn: 0.3966469	total: 4.66s	remaining: 5.39s
# 464:	learn: 0.3965136	total: 4.67s	remaining: 5.38s
# 465:	learn: 0.3963484	total: 4.68s	remaining: 5.37s
# 466:	learn: 0.3961899	total: 4.69s	remaining: 5.35s
# 467:	learn: 0.3960787	total: 4.7s	remaining: 5.34s
# 468:	learn: 0.3959280	total: 4.71s	remaining: 5.33s
# 469:	learn: 0.3957955	total: 4.72s	remaining: 5.32s
# 470:	learn: 0.3956207	total: 4.73s	remaining: 5.31s
# 471:	learn: 0.3953833	total: 4.74s	remaining: 5.3s
# 472:	learn: 0.3951340	total: 4.75s	remaining: 5.29s
# 473:	learn: 0.3949548	total: 4.76s	remaining: 5.28s
# 474:	learn: 0.3947043	total: 4.77s	remaining: 5.27s
# 475:	learn: 0.3945627	total: 4.78s	remaining: 5.26s
# 476:	learn: 0.3943280	total: 4.79s	remaining: 5.25s
# 477:	learn: 0.3941712	total: 4.8s	remaining: 5.24s
# 478:	learn: 0.3939525	total: 4.81s	remaining: 5.23s
# 479:	learn: 0.3937910	total: 4.82s	remaining: 5.22s
# 480:	learn: 0.3935491	total: 4.83s	remaining: 5.21s
# 481:	learn: 0.3933385	total: 4.84s	remaining: 5.2s
# 482:	learn: 0.3932026	total: 4.85s	remaining: 5.19s
# 483:	learn: 0.3930732	total: 4.86s	remaining: 5.18s
# 484:	learn: 0.3928252	total: 4.87s	remaining: 5.17s
# 485:	learn: 0.3926014	total: 4.88s	remaining: 5.16s
# 486:	learn: 0.3924432	total: 4.89s	remaining: 5.15s
# 487:	learn: 0.3922820	total: 4.9s	remaining: 5.14s
# 488:	learn: 0.3920595	total: 4.91s	remaining: 5.13s
# 489:	learn: 0.3918732	total: 4.92s	remaining: 5.12s
# 490:	learn: 0.3917340	total: 4.93s	remaining: 5.11s
# 491:	learn: 0.3915749	total: 4.94s	remaining: 5.1s
# 492:	learn: 0.3914330	total: 4.95s	remaining: 5.09s
# 493:	learn: 0.3912776	total: 4.96s	remaining: 5.08s
# 494:	learn: 0.3910902	total: 4.96s	remaining: 5.07s
# 495:	learn: 0.3909238	total: 4.98s	remaining: 5.06s
# 496:	learn: 0.3907685	total: 4.99s	remaining: 5.05s
# 497:	learn: 0.3905715	total: 5s	remaining: 5.04s
# 498:	learn: 0.3903658	total: 5.01s	remaining: 5.03s
# 499:	learn: 0.3901751	total: 5.02s	remaining: 5.02s
# 500:	learn: 0.3899671	total: 5.03s	remaining: 5.01s
# 501:	learn: 0.3898339	total: 5.04s	remaining: 5s
# 502:	learn: 0.3896996	total: 5.05s	remaining: 4.99s
# 503:	learn: 0.3895683	total: 5.06s	remaining: 4.98s
# 504:	learn: 0.3894227	total: 5.07s	remaining: 4.97s
# 505:	learn: 0.3892557	total: 5.08s	remaining: 4.96s
# 506:	learn: 0.3891085	total: 5.09s	remaining: 4.95s
# 507:	learn: 0.3889652	total: 5.1s	remaining: 4.94s
# 508:	learn: 0.3888009	total: 5.11s	remaining: 4.93s
# 509:	learn: 0.3886757	total: 5.12s	remaining: 4.92s
# 510:	learn: 0.3884946	total: 5.13s	remaining: 4.91s
# 511:	learn: 0.3883558	total: 5.13s	remaining: 4.89s
# 512:	learn: 0.3882203	total: 5.14s	remaining: 4.88s
# 513:	learn: 0.3880245	total: 5.16s	remaining: 4.88s
# 514:	learn: 0.3878468	total: 5.17s	remaining: 4.86s
# 515:	learn: 0.3877007	total: 5.17s	remaining: 4.85s
# 516:	learn: 0.3875563	total: 5.19s	remaining: 4.85s
# 517:	learn: 0.3873922	total: 5.2s	remaining: 4.84s
# 518:	learn: 0.3872224	total: 5.21s	remaining: 4.83s
# 519:	learn: 0.3870475	total: 5.22s	remaining: 4.82s
# 520:	learn: 0.3867871	total: 5.23s	remaining: 4.81s
# 521:	learn: 0.3866508	total: 5.24s	remaining: 4.8s
# 522:	learn: 0.3865039	total: 5.25s	remaining: 4.79s
# 523:	learn: 0.3862411	total: 5.26s	remaining: 4.78s
# 524:	learn: 0.3861138	total: 5.27s	remaining: 4.77s
# 525:	learn: 0.3859144	total: 5.28s	remaining: 4.75s
# 526:	learn: 0.3857572	total: 5.29s	remaining: 4.75s
# 527:	learn: 0.3856561	total: 5.3s	remaining: 4.73s
# 528:	learn: 0.3854955	total: 5.31s	remaining: 4.72s
# 529:	learn: 0.3853610	total: 5.32s	remaining: 4.71s
# 530:	learn: 0.3851826	total: 5.32s	remaining: 4.7s
# 531:	learn: 0.3849860	total: 5.33s	remaining: 4.69s
# 532:	learn: 0.3848427	total: 5.34s	remaining: 4.68s
# 533:	learn: 0.3846986	total: 5.35s	remaining: 4.67s
# 534:	learn: 0.3845181	total: 5.36s	remaining: 4.66s
# 535:	learn: 0.3843833	total: 5.37s	remaining: 4.65s
# 536:	learn: 0.3841803	total: 5.38s	remaining: 4.64s
# 537:	learn: 0.3840316	total: 5.4s	remaining: 4.64s
# 538:	learn: 0.3838439	total: 5.41s	remaining: 4.63s
# 539:	learn: 0.3836723	total: 5.42s	remaining: 4.62s
# 540:	learn: 0.3835255	total: 5.43s	remaining: 4.61s
# 541:	learn: 0.3833480	total: 5.44s	remaining: 4.6s
# 542:	learn: 0.3831452	total: 5.45s	remaining: 4.59s
# 543:	learn: 0.3829968	total: 5.46s	remaining: 4.58s
# 544:	learn: 0.3828284	total: 5.47s	remaining: 4.57s
# 545:	learn: 0.3826729	total: 5.48s	remaining: 4.56s
# 546:	learn: 0.3825070	total: 5.49s	remaining: 4.55s
# 547:	learn: 0.3823581	total: 5.5s	remaining: 4.54s
# 548:	learn: 0.3821919	total: 5.51s	remaining: 4.53s
# 549:	learn: 0.3820685	total: 5.52s	remaining: 4.52s
# 550:	learn: 0.3818770	total: 5.53s	remaining: 4.5s
# 551:	learn: 0.3817319	total: 5.54s	remaining: 4.5s
# 552:	learn: 0.3815536	total: 5.55s	remaining: 4.48s
# 553:	learn: 0.3813986	total: 5.56s	remaining: 4.47s
# 554:	learn: 0.3812680	total: 5.57s	remaining: 4.46s
# 555:	learn: 0.3810644	total: 5.58s	remaining: 4.45s
# 556:	learn: 0.3808532	total: 5.59s	remaining: 4.44s
# 557:	learn: 0.3806941	total: 5.6s	remaining: 4.43s
# 558:	learn: 0.3805135	total: 5.62s	remaining: 4.43s
# 559:	learn: 0.3803187	total: 5.63s	remaining: 4.42s
# 560:	learn: 0.3801525	total: 5.64s	remaining: 4.41s
# 561:	learn: 0.3799802	total: 5.65s	remaining: 4.4s
# 562:	learn: 0.3798356	total: 5.66s	remaining: 4.39s
# 563:	learn: 0.3796950	total: 5.67s	remaining: 4.38s
# 564:	learn: 0.3794856	total: 5.68s	remaining: 4.37s
# 565:	learn: 0.3793041	total: 5.68s	remaining: 4.36s
# 566:	learn: 0.3791494	total: 5.7s	remaining: 4.35s
# 567:	learn: 0.3788838	total: 5.71s	remaining: 4.34s
# 568:	learn: 0.3786518	total: 5.71s	remaining: 4.33s
# 569:	learn: 0.3784808	total: 5.72s	remaining: 4.32s
# 570:	learn: 0.3783481	total: 5.73s	remaining: 4.31s
# 571:	learn: 0.3782075	total: 5.74s	remaining: 4.3s
# 572:	learn: 0.3780870	total: 5.75s	remaining: 4.29s
# 573:	learn: 0.3779742	total: 5.76s	remaining: 4.28s
# 574:	learn: 0.3778538	total: 5.77s	remaining: 4.27s
# 575:	learn: 0.3776858	total: 5.78s	remaining: 4.25s
# 576:	learn: 0.3775820	total: 5.79s	remaining: 4.25s
# 577:	learn: 0.3774373	total: 5.8s	remaining: 4.24s
# 578:	learn: 0.3772630	total: 5.81s	remaining: 4.22s
# 579:	learn: 0.3771420	total: 5.83s	remaining: 4.22s
# 580:	learn: 0.3769777	total: 5.84s	remaining: 4.21s
# 581:	learn: 0.3768032	total: 5.85s	remaining: 4.2s
# 582:	learn: 0.3767108	total: 5.86s	remaining: 4.19s
# 583:	learn: 0.3765696	total: 5.87s	remaining: 4.18s
# 584:	learn: 0.3764205	total: 5.88s	remaining: 4.17s
# 585:	learn: 0.3762495	total: 5.89s	remaining: 4.16s
# 586:	learn: 0.3761026	total: 5.9s	remaining: 4.15s
# 587:	learn: 0.3759646	total: 5.91s	remaining: 4.14s
# 588:	learn: 0.3757545	total: 5.92s	remaining: 4.13s
# 589:	learn: 0.3755229	total: 5.93s	remaining: 4.12s
# 590:	learn: 0.3753603	total: 5.94s	remaining: 4.11s
# 591:	learn: 0.3752275	total: 5.95s	remaining: 4.1s
# 592:	learn: 0.3750537	total: 5.96s	remaining: 4.09s
# 593:	learn: 0.3749357	total: 5.97s	remaining: 4.08s
# 594:	learn: 0.3747575	total: 5.98s	remaining: 4.07s
# 595:	learn: 0.3745888	total: 5.99s	remaining: 4.06s
# 596:	learn: 0.3744716	total: 6s	remaining: 4.05s
# 597:	learn: 0.3743349	total: 6s	remaining: 4.04s
# 598:	learn: 0.3742058	total: 6.01s	remaining: 4.03s
# 599:	learn: 0.3740674	total: 6.02s	remaining: 4.02s
# 600:	learn: 0.3739176	total: 6.05s	remaining: 4.01s
# 601:	learn: 0.3737666	total: 6.06s	remaining: 4s
# 602:	learn: 0.3736215	total: 6.07s	remaining: 3.99s
# 603:	learn: 0.3735129	total: 6.08s	remaining: 3.98s
# 604:	learn: 0.3733655	total: 6.08s	remaining: 3.97s
# 605:	learn: 0.3731835	total: 6.09s	remaining: 3.96s
# 606:	learn: 0.3729628	total: 6.11s	remaining: 3.95s
# 607:	learn: 0.3727803	total: 6.11s	remaining: 3.94s
# 608:	learn: 0.3726402	total: 6.12s	remaining: 3.93s
# 609:	learn: 0.3724100	total: 6.13s	remaining: 3.92s
# 610:	learn: 0.3722640	total: 6.14s	remaining: 3.91s
# 611:	learn: 0.3720151	total: 6.15s	remaining: 3.9s
# 612:	learn: 0.3718908	total: 6.16s	remaining: 3.89s
# 613:	learn: 0.3717472	total: 6.17s	remaining: 3.88s
# 614:	learn: 0.3716385	total: 6.18s	remaining: 3.87s
# 615:	learn: 0.3714801	total: 6.19s	remaining: 3.86s
# 616:	learn: 0.3713326	total: 6.2s	remaining: 3.85s
# 617:	learn: 0.3711846	total: 6.21s	remaining: 3.84s
# 618:	learn: 0.3710230	total: 6.22s	remaining: 3.83s
# 619:	learn: 0.3708440	total: 6.23s	remaining: 3.82s
# 620:	learn: 0.3706523	total: 6.24s	remaining: 3.81s
# 621:	learn: 0.3704202	total: 6.26s	remaining: 3.81s
# 622:	learn: 0.3702625	total: 6.27s	remaining: 3.79s
# 623:	learn: 0.3700800	total: 6.28s	remaining: 3.79s
# 624:	learn: 0.3698800	total: 6.29s	remaining: 3.78s
# 625:	learn: 0.3697312	total: 6.3s	remaining: 3.77s
# 626:	learn: 0.3695626	total: 6.31s	remaining: 3.75s
# 627:	learn: 0.3693894	total: 6.32s	remaining: 3.75s
# 628:	learn: 0.3692715	total: 6.33s	remaining: 3.73s
# 629:	learn: 0.3691069	total: 6.34s	remaining: 3.73s
# 630:	learn: 0.3689643	total: 6.35s	remaining: 3.71s
# 631:	learn: 0.3686918	total: 6.36s	remaining: 3.7s
# 632:	learn: 0.3685327	total: 6.37s	remaining: 3.69s
# 633:	learn: 0.3683916	total: 6.38s	remaining: 3.68s
# 634:	learn: 0.3682513	total: 6.39s	remaining: 3.67s
# 635:	learn: 0.3680782	total: 6.4s	remaining: 3.66s
# 636:	learn: 0.3678909	total: 6.41s	remaining: 3.65s
# 637:	learn: 0.3677394	total: 6.42s	remaining: 3.64s
# 638:	learn: 0.3676462	total: 6.43s	remaining: 3.63s
# 639:	learn: 0.3675255	total: 6.44s	remaining: 3.62s
# 640:	learn: 0.3674120	total: 6.45s	remaining: 3.61s
# 641:	learn: 0.3672848	total: 6.46s	remaining: 3.6s
# 642:	learn: 0.3671876	total: 6.48s	remaining: 3.6s
# 643:	learn: 0.3670346	total: 6.49s	remaining: 3.59s
# 644:	learn: 0.3668302	total: 6.5s	remaining: 3.58s
# 645:	learn: 0.3667117	total: 6.51s	remaining: 3.57s
# 646:	learn: 0.3665723	total: 6.52s	remaining: 3.56s
# 647:	learn: 0.3663738	total: 6.53s	remaining: 3.55s
# 648:	learn: 0.3662314	total: 6.54s	remaining: 3.54s
# 649:	learn: 0.3660592	total: 6.55s	remaining: 3.53s
# 650:	learn: 0.3659529	total: 6.56s	remaining: 3.52s
# 651:	learn: 0.3657938	total: 6.57s	remaining: 3.51s
# 652:	learn: 0.3656689	total: 6.58s	remaining: 3.5s
# 653:	learn: 0.3655355	total: 6.59s	remaining: 3.48s
# 654:	learn: 0.3653164	total: 6.6s	remaining: 3.47s
# 655:	learn: 0.3651827	total: 6.61s	remaining: 3.46s
# 656:	learn: 0.3650540	total: 6.62s	remaining: 3.45s
# 657:	learn: 0.3648446	total: 6.63s	remaining: 3.44s
# 658:	learn: 0.3646689	total: 6.63s	remaining: 3.43s
# 659:	learn: 0.3645239	total: 6.64s	remaining: 3.42s
# 660:	learn: 0.3643749	total: 6.65s	remaining: 3.41s
# 661:	learn: 0.3642471	total: 6.66s	remaining: 3.4s
# 662:	learn: 0.3640412	total: 6.67s	remaining: 3.39s
# 663:	learn: 0.3639206	total: 6.68s	remaining: 3.38s
# 664:	learn: 0.3637726	total: 6.7s	remaining: 3.37s
# 665:	learn: 0.3636660	total: 6.71s	remaining: 3.36s
# 666:	learn: 0.3634958	total: 6.72s	remaining: 3.35s
# 667:	learn: 0.3632491	total: 6.73s	remaining: 3.34s
# 668:	learn: 0.3631253	total: 6.74s	remaining: 3.33s
# 669:	learn: 0.3629095	total: 6.75s	remaining: 3.32s
# 670:	learn: 0.3627446	total: 6.75s	remaining: 3.31s
# 671:	learn: 0.3626291	total: 6.76s	remaining: 3.3s
# 672:	learn: 0.3625014	total: 6.77s	remaining: 3.29s
# 673:	learn: 0.3623925	total: 6.78s	remaining: 3.28s
# 674:	learn: 0.3622495	total: 6.79s	remaining: 3.27s
# 675:	learn: 0.3620793	total: 6.8s	remaining: 3.26s
# 676:	learn: 0.3619166	total: 6.81s	remaining: 3.25s
# 677:	learn: 0.3617916	total: 6.82s	remaining: 3.24s
# 678:	learn: 0.3616038	total: 6.83s	remaining: 3.23s
# 679:	learn: 0.3614693	total: 6.84s	remaining: 3.22s
# 680:	learn: 0.3612833	total: 6.85s	remaining: 3.21s
# 681:	learn: 0.3611001	total: 6.86s	remaining: 3.2s
# 682:	learn: 0.3609774	total: 6.87s	remaining: 3.19s
# 683:	learn: 0.3608454	total: 6.88s	remaining: 3.18s
# 684:	learn: 0.3606498	total: 6.89s	remaining: 3.17s
# 685:	learn: 0.3605204	total: 6.9s	remaining: 3.16s
# 686:	learn: 0.3603616	total: 6.91s	remaining: 3.15s
# 687:	learn: 0.3601595	total: 6.92s	remaining: 3.14s
# 688:	learn: 0.3600118	total: 6.93s	remaining: 3.13s
# 689:	learn: 0.3598539	total: 6.94s	remaining: 3.12s
# 690:	learn: 0.3596763	total: 6.95s	remaining: 3.11s
# 691:	learn: 0.3595391	total: 6.96s	remaining: 3.1s
# 692:	learn: 0.3593584	total: 6.97s	remaining: 3.09s
# 693:	learn: 0.3591832	total: 6.98s	remaining: 3.08s
# 694:	learn: 0.3590595	total: 6.99s	remaining: 3.07s
# 695:	learn: 0.3588791	total: 7s	remaining: 3.06s
# 696:	learn: 0.3587398	total: 7.01s	remaining: 3.05s
# 697:	learn: 0.3585552	total: 7.02s	remaining: 3.04s
# 698:	learn: 0.3584384	total: 7.03s	remaining: 3.03s
# 699:	learn: 0.3582820	total: 7.04s	remaining: 3.02s
# 700:	learn: 0.3581140	total: 7.05s	remaining: 3s
# 701:	learn: 0.3579857	total: 7.06s	remaining: 3s
# 702:	learn: 0.3578849	total: 7.07s	remaining: 2.98s
# 703:	learn: 0.3577212	total: 7.08s	remaining: 2.97s
# 704:	learn: 0.3576395	total: 7.08s	remaining: 2.96s
# 705:	learn: 0.3575320	total: 7.11s	remaining: 2.96s
# 706:	learn: 0.3573746	total: 7.12s	remaining: 2.95s
# 707:	learn: 0.3572343	total: 7.13s	remaining: 2.94s
# 708:	learn: 0.3570535	total: 7.14s	remaining: 2.93s
# 709:	learn: 0.3569163	total: 7.15s	remaining: 2.92s
# 710:	learn: 0.3567560	total: 7.16s	remaining: 2.91s
# 711:	learn: 0.3565707	total: 7.17s	remaining: 2.9s
# 712:	learn: 0.3563858	total: 7.18s	remaining: 2.89s
# 713:	learn: 0.3562442	total: 7.19s	remaining: 2.88s
# 714:	learn: 0.3560490	total: 7.2s	remaining: 2.87s
# 715:	learn: 0.3559468	total: 7.21s	remaining: 2.86s
# 716:	learn: 0.3557429	total: 7.21s	remaining: 2.85s
# 717:	learn: 0.3555948	total: 7.22s	remaining: 2.84s
# 718:	learn: 0.3554803	total: 7.23s	remaining: 2.83s
# 719:	learn: 0.3552964	total: 7.24s	remaining: 2.82s
# 720:	learn: 0.3551035	total: 7.25s	remaining: 2.81s
# 721:	learn: 0.3549359	total: 7.26s	remaining: 2.8s
# 722:	learn: 0.3547931	total: 7.27s	remaining: 2.79s
# 723:	learn: 0.3546685	total: 7.28s	remaining: 2.78s
# 724:	learn: 0.3545687	total: 7.29s	remaining: 2.77s
# 725:	learn: 0.3544403	total: 7.3s	remaining: 2.75s
# 726:	learn: 0.3543245	total: 7.32s	remaining: 2.75s
# 727:	learn: 0.3542091	total: 7.33s	remaining: 2.74s
# 728:	learn: 0.3540119	total: 7.34s	remaining: 2.73s
# 729:	learn: 0.3537702	total: 7.35s	remaining: 2.72s
# 730:	learn: 0.3535887	total: 7.36s	remaining: 2.71s
# 731:	learn: 0.3534814	total: 7.37s	remaining: 2.7s
# 732:	learn: 0.3533504	total: 7.38s	remaining: 2.69s
# 733:	learn: 0.3532241	total: 7.39s	remaining: 2.68s
# 734:	learn: 0.3530770	total: 7.4s	remaining: 2.67s
# 735:	learn: 0.3529122	total: 7.41s	remaining: 2.66s
# 736:	learn: 0.3527592	total: 7.42s	remaining: 2.65s
# 737:	learn: 0.3526725	total: 7.43s	remaining: 2.64s
# 738:	learn: 0.3525354	total: 7.44s	remaining: 2.63s
# 739:	learn: 0.3524169	total: 7.45s	remaining: 2.62s
# 740:	learn: 0.3522855	total: 7.46s	remaining: 2.61s
# 741:	learn: 0.3521643	total: 7.47s	remaining: 2.6s
# 742:	learn: 0.3519987	total: 7.48s	remaining: 2.59s
# 743:	learn: 0.3518789	total: 7.49s	remaining: 2.58s
# 744:	learn: 0.3517707	total: 7.5s	remaining: 2.57s
# 745:	learn: 0.3516086	total: 7.51s	remaining: 2.56s
# 746:	learn: 0.3514843	total: 7.53s	remaining: 2.55s
# 747:	learn: 0.3513536	total: 7.54s	remaining: 2.54s
# 748:	learn: 0.3512544	total: 7.55s	remaining: 2.53s
# 749:	learn: 0.3511550	total: 7.56s	remaining: 2.52s
# 750:	learn: 0.3510125	total: 7.57s	remaining: 2.51s
# 751:	learn: 0.3508749	total: 7.58s	remaining: 2.5s
# 752:	learn: 0.3507215	total: 7.59s	remaining: 2.49s
# 753:	learn: 0.3506099	total: 7.6s	remaining: 2.48s
# 754:	learn: 0.3504470	total: 7.61s	remaining: 2.47s
# 755:	learn: 0.3502899	total: 7.62s	remaining: 2.46s
# 756:	learn: 0.3501779	total: 7.63s	remaining: 2.45s
# 757:	learn: 0.3500236	total: 7.64s	remaining: 2.44s
# 758:	learn: 0.3498801	total: 7.64s	remaining: 2.43s
# 759:	learn: 0.3497597	total: 7.66s	remaining: 2.42s
# 760:	learn: 0.3495816	total: 7.67s	remaining: 2.41s
# 761:	learn: 0.3493966	total: 7.67s	remaining: 2.4s
# 762:	learn: 0.3492584	total: 7.68s	remaining: 2.39s
# 763:	learn: 0.3490881	total: 7.69s	remaining: 2.38s
# 764:	learn: 0.3489841	total: 7.7s	remaining: 2.37s
# 765:	learn: 0.3488217	total: 7.71s	remaining: 2.36s
# 766:	learn: 0.3486990	total: 7.72s	remaining: 2.35s
# 767:	learn: 0.3485581	total: 7.75s	remaining: 2.34s
# 768:	learn: 0.3484455	total: 7.75s	remaining: 2.33s
# 769:	learn: 0.3482928	total: 7.76s	remaining: 2.32s
# 770:	learn: 0.3481882	total: 7.77s	remaining: 2.31s
# 771:	learn: 0.3480081	total: 7.78s	remaining: 2.3s
# 772:	learn: 0.3478619	total: 7.79s	remaining: 2.29s
# 773:	learn: 0.3477156	total: 7.8s	remaining: 2.28s
# 774:	learn: 0.3475793	total: 7.81s	remaining: 2.27s
# 775:	learn: 0.3474290	total: 7.82s	remaining: 2.26s
# 776:	learn: 0.3473204	total: 7.83s	remaining: 2.25s
# 777:	learn: 0.3472189	total: 7.84s	remaining: 2.24s
# 778:	learn: 0.3471034	total: 7.85s	remaining: 2.23s
# 779:	learn: 0.3469330	total: 7.86s	remaining: 2.22s
# 780:	learn: 0.3467680	total: 7.87s	remaining: 2.21s
# 781:	learn: 0.3465695	total: 7.88s	remaining: 2.2s
# 782:	learn: 0.3464771	total: 7.89s	remaining: 2.19s
# 783:	learn: 0.3463007	total: 7.9s	remaining: 2.18s
# 784:	learn: 0.3461563	total: 7.91s	remaining: 2.17s
# 785:	learn: 0.3460364	total: 7.92s	remaining: 2.15s
# 786:	learn: 0.3458684	total: 7.93s	remaining: 2.15s
# 787:	learn: 0.3456947	total: 7.94s	remaining: 2.13s
# 788:	learn: 0.3455969	total: 7.96s	remaining: 2.13s
# 789:	learn: 0.3454563	total: 7.97s	remaining: 2.12s
# 790:	learn: 0.3453277	total: 7.98s	remaining: 2.11s
# 791:	learn: 0.3451830	total: 7.99s	remaining: 2.1s
# 792:	learn: 0.3450657	total: 8s	remaining: 2.09s
# 793:	learn: 0.3449145	total: 8.01s	remaining: 2.08s
# 794:	learn: 0.3447395	total: 8.02s	remaining: 2.07s
# 795:	learn: 0.3445790	total: 8.03s	remaining: 2.06s
# 796:	learn: 0.3444644	total: 8.04s	remaining: 2.05s
# 797:	learn: 0.3443682	total: 8.05s	remaining: 2.04s
# 798:	learn: 0.3442257	total: 8.06s	remaining: 2.03s
# 799:	learn: 0.3441092	total: 8.07s	remaining: 2.02s
# 800:	learn: 0.3439657	total: 8.08s	remaining: 2.01s
# 801:	learn: 0.3437827	total: 8.09s	remaining: 2s
# 802:	learn: 0.3436694	total: 8.1s	remaining: 1.99s
# 803:	learn: 0.3434341	total: 8.11s	remaining: 1.98s
# 804:	learn: 0.3433076	total: 8.12s	remaining: 1.97s
# 805:	learn: 0.3432002	total: 8.12s	remaining: 1.96s
# 806:	learn: 0.3430295	total: 8.13s	remaining: 1.95s
# 807:	learn: 0.3429724	total: 8.14s	remaining: 1.94s
# 808:	learn: 0.3428728	total: 8.15s	remaining: 1.93s
# 809:	learn: 0.3427172	total: 8.18s	remaining: 1.92s
# 810:	learn: 0.3425355	total: 8.19s	remaining: 1.91s
# 811:	learn: 0.3424256	total: 8.2s	remaining: 1.9s
# 812:	learn: 0.3423293	total: 8.21s	remaining: 1.89s
# 813:	learn: 0.3422441	total: 8.22s	remaining: 1.88s
# 814:	learn: 0.3421020	total: 8.23s	remaining: 1.87s
# 815:	learn: 0.3419388	total: 8.24s	remaining: 1.86s
# 816:	learn: 0.3417949	total: 8.25s	remaining: 1.85s
# 817:	learn: 0.3416829	total: 8.26s	remaining: 1.84s
# 818:	learn: 0.3415030	total: 8.27s	remaining: 1.83s
# 819:	learn: 0.3413543	total: 8.28s	remaining: 1.82s
# 820:	learn: 0.3412439	total: 8.29s	remaining: 1.81s
# 821:	learn: 0.3411489	total: 8.3s	remaining: 1.8s
# 822:	learn: 0.3410173	total: 8.3s	remaining: 1.79s
# 823:	learn: 0.3408946	total: 8.31s	remaining: 1.78s
# 824:	learn: 0.3407704	total: 8.32s	remaining: 1.76s
# 825:	learn: 0.3406714	total: 8.33s	remaining: 1.75s
# 826:	learn: 0.3405461	total: 8.34s	remaining: 1.75s
# 827:	learn: 0.3404357	total: 8.35s	remaining: 1.74s
# 828:	learn: 0.3403371	total: 8.36s	remaining: 1.73s
# 829:	learn: 0.3402477	total: 8.37s	remaining: 1.72s
# 830:	learn: 0.3401159	total: 8.4s	remaining: 1.71s
# 831:	learn: 0.3399785	total: 8.41s	remaining: 1.7s
# 832:	learn: 0.3398441	total: 8.41s	remaining: 1.69s
# 833:	learn: 0.3397355	total: 8.43s	remaining: 1.68s
# 834:	learn: 0.3395775	total: 8.44s	remaining: 1.67s
# 835:	learn: 0.3394784	total: 8.44s	remaining: 1.66s
# 836:	learn: 0.3393786	total: 8.45s	remaining: 1.65s
# 837:	learn: 0.3392413	total: 8.46s	remaining: 1.64s
# 838:	learn: 0.3391769	total: 8.47s	remaining: 1.63s
# 839:	learn: 0.3390601	total: 8.48s	remaining: 1.61s
# 840:	learn: 0.3389460	total: 8.49s	remaining: 1.6s
# 841:	learn: 0.3387899	total: 8.5s	remaining: 1.59s
# 842:	learn: 0.3385993	total: 8.51s	remaining: 1.58s
# 843:	learn: 0.3384829	total: 8.52s	remaining: 1.57s
# 844:	learn: 0.3382775	total: 8.53s	remaining: 1.56s
# 845:	learn: 0.3381508	total: 8.54s	remaining: 1.55s
# 846:	learn: 0.3380566	total: 8.55s	remaining: 1.54s
# 847:	learn: 0.3378612	total: 8.56s	remaining: 1.53s
# 848:	learn: 0.3377220	total: 8.57s	remaining: 1.52s
# 849:	learn: 0.3376115	total: 8.58s	remaining: 1.51s
# 850:	learn: 0.3374236	total: 8.6s	remaining: 1.5s
# 851:	learn: 0.3373431	total: 8.61s	remaining: 1.5s
# 852:	learn: 0.3372180	total: 8.62s	remaining: 1.49s
# 853:	learn: 0.3371147	total: 8.63s	remaining: 1.48s
# 854:	learn: 0.3369862	total: 8.64s	remaining: 1.47s
# 855:	learn: 0.3369098	total: 8.65s	remaining: 1.46s
# 856:	learn: 0.3368176	total: 8.66s	remaining: 1.45s
# 857:	learn: 0.3366979	total: 8.67s	remaining: 1.43s
# 858:	learn: 0.3366265	total: 8.68s	remaining: 1.42s
# 859:	learn: 0.3365236	total: 8.69s	remaining: 1.41s
# 860:	learn: 0.3364088	total: 8.7s	remaining: 1.4s
# 861:	learn: 0.3362371	total: 8.71s	remaining: 1.39s
# 862:	learn: 0.3361184	total: 8.72s	remaining: 1.38s
# 863:	learn: 0.3359725	total: 8.73s	remaining: 1.37s
# 864:	learn: 0.3358734	total: 8.74s	remaining: 1.36s
# 865:	learn: 0.3357398	total: 8.75s	remaining: 1.35s
# 866:	learn: 0.3356017	total: 8.76s	remaining: 1.34s
# 867:	learn: 0.3354250	total: 8.77s	remaining: 1.33s
# 868:	learn: 0.3353037	total: 8.78s	remaining: 1.32s
# 869:	learn: 0.3351556	total: 8.78s	remaining: 1.31s
# 870:	learn: 0.3350574	total: 8.79s	remaining: 1.3s
# 871:	learn: 0.3349200	total: 8.81s	remaining: 1.29s
# 872:	learn: 0.3348026	total: 8.82s	remaining: 1.28s
# 873:	learn: 0.3347043	total: 8.83s	remaining: 1.27s
# 874:	learn: 0.3346578	total: 8.84s	remaining: 1.26s
# 875:	learn: 0.3345634	total: 8.85s	remaining: 1.25s
# 876:	learn: 0.3344174	total: 8.86s	remaining: 1.24s
# 877:	learn: 0.3342684	total: 8.87s	remaining: 1.23s
# 878:	learn: 0.3341215	total: 8.88s	remaining: 1.22s
# 879:	learn: 0.3339860	total: 8.88s	remaining: 1.21s
# 880:	learn: 0.3338586	total: 8.89s	remaining: 1.2s
# 881:	learn: 0.3338239	total: 8.9s	remaining: 1.19s
# 882:	learn: 0.3337370	total: 8.91s	remaining: 1.18s
# 883:	learn: 0.3335643	total: 8.92s	remaining: 1.17s
# 884:	learn: 0.3334493	total: 8.93s	remaining: 1.16s
# 885:	learn: 0.3333645	total: 8.94s	remaining: 1.15s
# 886:	learn: 0.3332253	total: 8.95s	remaining: 1.14s
# 887:	learn: 0.3331157	total: 8.96s	remaining: 1.13s
# 888:	learn: 0.3329622	total: 8.97s	remaining: 1.12s
# 889:	learn: 0.3327976	total: 8.98s	remaining: 1.11s
# 890:	learn: 0.3327068	total: 8.99s	remaining: 1.1s
# 891:	learn: 0.3325834	total: 9.01s	remaining: 1.09s
# 892:	learn: 0.3324131	total: 9.02s	remaining: 1.08s
# 893:	learn: 0.3323445	total: 9.02s	remaining: 1.07s
# 894:	learn: 0.3322974	total: 9.03s	remaining: 1.06s
# 895:	learn: 0.3321912	total: 9.04s	remaining: 1.05s
# 896:	learn: 0.3321046	total: 9.05s	remaining: 1.04s
# 897:	learn: 0.3319693	total: 9.06s	remaining: 1.03s
# 898:	learn: 0.3318378	total: 9.07s	remaining: 1.02s
# 899:	learn: 0.3317442	total: 9.08s	remaining: 1.01s
# 900:	learn: 0.3315624	total: 9.09s	remaining: 999ms
# 901:	learn: 0.3314565	total: 9.1s	remaining: 989ms
# 902:	learn: 0.3313349	total: 9.11s	remaining: 979ms
# 903:	learn: 0.3312099	total: 9.12s	remaining: 969ms
# 904:	learn: 0.3311141	total: 9.13s	remaining: 958ms
# 905:	learn: 0.3309706	total: 9.14s	remaining: 948ms
# 906:	learn: 0.3308326	total: 9.15s	remaining: 938ms
# 907:	learn: 0.3306714	total: 9.16s	remaining: 928ms
# 908:	learn: 0.3305282	total: 9.17s	remaining: 918ms
# 909:	learn: 0.3304081	total: 9.18s	remaining: 908ms
# 910:	learn: 0.3303051	total: 9.19s	remaining: 898ms
# 911:	learn: 0.3301751	total: 9.2s	remaining: 887ms
# 912:	learn: 0.3300229	total: 9.22s	remaining: 879ms
# 913:	learn: 0.3299084	total: 9.23s	remaining: 869ms
# 914:	learn: 0.3297926	total: 9.24s	remaining: 858ms
# 915:	learn: 0.3296697	total: 9.25s	remaining: 848ms
# 916:	learn: 0.3295858	total: 9.26s	remaining: 838ms
# 917:	learn: 0.3294394	total: 9.27s	remaining: 828ms
# 918:	learn: 0.3293430	total: 9.28s	remaining: 818ms
# 919:	learn: 0.3292324	total: 9.29s	remaining: 808ms
# 920:	learn: 0.3291081	total: 9.3s	remaining: 798ms
# 921:	learn: 0.3289989	total: 9.31s	remaining: 787ms
# 922:	learn: 0.3289053	total: 9.32s	remaining: 777ms
# 923:	learn: 0.3287593	total: 9.33s	remaining: 767ms
# 924:	learn: 0.3286349	total: 9.34s	remaining: 757ms
# 925:	learn: 0.3284803	total: 9.35s	remaining: 747ms
# 926:	learn: 0.3282699	total: 9.36s	remaining: 737ms
# 927:	learn: 0.3281177	total: 9.37s	remaining: 727ms
# 928:	learn: 0.3279522	total: 9.37s	remaining: 716ms
# 929:	learn: 0.3277996	total: 9.38s	remaining: 706ms
# 930:	learn: 0.3276549	total: 9.39s	remaining: 696ms
# 931:	learn: 0.3275742	total: 9.4s	remaining: 686ms
# 932:	learn: 0.3274456	total: 9.41s	remaining: 676ms
# 933:	learn: 0.3273172	total: 9.44s	remaining: 667ms
# 934:	learn: 0.3272314	total: 9.45s	remaining: 657ms
# 935:	learn: 0.3271772	total: 9.46s	remaining: 647ms
# 936:	learn: 0.3270581	total: 9.46s	remaining: 636ms
# 937:	learn: 0.3268643	total: 9.47s	remaining: 626ms
# 938:	learn: 0.3266743	total: 9.48s	remaining: 616ms
# 939:	learn: 0.3266380	total: 9.49s	remaining: 606ms
# 940:	learn: 0.3264647	total: 9.5s	remaining: 596ms
# 941:	learn: 0.3263877	total: 9.51s	remaining: 586ms
# 942:	learn: 0.3263018	total: 9.52s	remaining: 576ms
# 943:	learn: 0.3261894	total: 9.53s	remaining: 565ms
# 944:	learn: 0.3260671	total: 9.54s	remaining: 555ms
# 945:	learn: 0.3259352	total: 9.55s	remaining: 545ms
# 946:	learn: 0.3258185	total: 9.56s	remaining: 535ms
# 947:	learn: 0.3257471	total: 9.57s	remaining: 525ms
# 948:	learn: 0.3256086	total: 9.58s	remaining: 515ms
# 949:	learn: 0.3254621	total: 9.59s	remaining: 505ms
# 950:	learn: 0.3253384	total: 9.6s	remaining: 495ms
# 951:	learn: 0.3251504	total: 9.61s	remaining: 484ms
# 952:	learn: 0.3250737	total: 9.62s	remaining: 474ms
# 953:	learn: 0.3249579	total: 9.63s	remaining: 464ms
# 954:	learn: 0.3247957	total: 9.65s	remaining: 455ms
# 955:	learn: 0.3246837	total: 9.66s	remaining: 445ms
# 956:	learn: 0.3245453	total: 9.67s	remaining: 434ms
# 957:	learn: 0.3244453	total: 9.68s	remaining: 424ms
# 958:	learn: 0.3243529	total: 9.69s	remaining: 414ms
# 959:	learn: 0.3242316	total: 9.7s	remaining: 404ms
# 960:	learn: 0.3241507	total: 9.71s	remaining: 394ms
# 961:	learn: 0.3240432	total: 9.72s	remaining: 384ms
# 962:	learn: 0.3239188	total: 9.73s	remaining: 374ms
# 963:	learn: 0.3238218	total: 9.74s	remaining: 364ms
# 964:	learn: 0.3236693	total: 9.74s	remaining: 353ms
# 965:	learn: 0.3235831	total: 9.76s	remaining: 343ms
# 966:	learn: 0.3234463	total: 9.76s	remaining: 333ms
# 967:	learn: 0.3233560	total: 9.77s	remaining: 323ms
# 968:	learn: 0.3232403	total: 9.78s	remaining: 313ms
# 969:	learn: 0.3230841	total: 9.79s	remaining: 303ms
# 970:	learn: 0.3229272	total: 9.8s	remaining: 293ms
# 971:	learn: 0.3228389	total: 9.81s	remaining: 283ms
# 972:	learn: 0.3226958	total: 9.82s	remaining: 273ms
# 973:	learn: 0.3225869	total: 9.83s	remaining: 262ms
# 974:	learn: 0.3224794	total: 9.84s	remaining: 252ms
# 975:	learn: 0.3223204	total: 9.87s	remaining: 243ms
# 976:	learn: 0.3222451	total: 9.88s	remaining: 232ms
# 977:	learn: 0.3221498	total: 9.88s	remaining: 222ms
# 978:	learn: 0.3220143	total: 9.89s	remaining: 212ms
# 979:	learn: 0.3218482	total: 9.9s	remaining: 202ms
# 980:	learn: 0.3217953	total: 9.91s	remaining: 192ms
# 981:	learn: 0.3216786	total: 9.92s	remaining: 182ms
# 982:	learn: 0.3215818	total: 9.93s	remaining: 172ms
# 983:	learn: 0.3214393	total: 9.94s	remaining: 162ms
# 984:	learn: 0.3212858	total: 9.95s	remaining: 152ms
# 985:	learn: 0.3211664	total: 9.96s	remaining: 141ms
# 986:	learn: 0.3210911	total: 9.97s	remaining: 131ms
# 987:	learn: 0.3209808	total: 9.98s	remaining: 121ms
# 988:	learn: 0.3208260	total: 9.99s	remaining: 111ms
# 989:	learn: 0.3207730	total: 10s	remaining: 101ms
# 990:	learn: 0.3206723	total: 10s	remaining: 90.9ms
# 991:	learn: 0.3205454	total: 10s	remaining: 80.8ms
# 992:	learn: 0.3204283	total: 10s	remaining: 70.7ms
# 993:	learn: 0.3203080	total: 10s	remaining: 60.6ms
# 994:	learn: 0.3201917	total: 10s	remaining: 50.5ms
# 995:	learn: 0.3200692	total: 10.1s	remaining: 40.4ms
# 996:	learn: 0.3199374	total: 10.1s	remaining: 30.3ms
# 997:	learn: 0.3197967	total: 10.1s	remaining: 20.2ms
# 998:	learn: 0.3196566	total: 10.1s	remaining: 10.1ms
# 999:	learn: 0.3195279	total: 10.1s	remaining: 0us

# %% [markdown]
# * Предварительный набор признаков

# %%
important_features_top = show_feature_importances(X.columns, model.feature_importances_, get_top=15)

# %% [markdown]
# * Отобранные признаки для использования

# %%
feats = ['Home Ownership', 'Annual Income', 
         'Years in current job',
         'Number of Open Accounts', 
         'Years of Credit History',
         'Maximum Open Credit', 
         'Number of Credit Problems',
         'Purpose', 
         'Term',
         'Current Loan Amount', 
         'Current Credit Balance', 
         'Monthly Debt',
         'Credit Score']
# FEATS_IMP = feats

# %% [markdown]
# **Стандартизация данных**

# %%
def standart_df(df_train, feats):

    scaler = StandardScaler()

    df_norm = df_train.copy()
    df_norm[feats] = scaler.fit_transform(df_norm[feats])
    data = df_norm.copy()
    
    return data

# %%
data=standart_df(df_train, feats)

# %% [markdown]
# **Балансировка данных**

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler

# %%
def balans_df(X,y):
    '''проводит балансировку данных'''
    
    ros = RandomOverSampler(random_state=42)
    X_resampled, y_resampled = ros.fit_resample(X, y)
    
    print('Resampled dataset shape %s' % Counter(y_resampled))
    return X_resampled, y_resampled

# %%
X = data[feats]
y = data['Credit Default']
print('Before sampled dataset shape %s' % Counter(y))
# Out:
# Before sampled dataset shape Counter({0.0: 5387, 1.0: 2113})

# %%
# Баланс в целевой переменной после оверсэмплинга
X_resampled,y_resampled = balans_df(X,y)
# Out:
# Resampled dataset shape Counter({0.0: 5387, 1.0: 5387})

# %% [markdown]
# **Разбиваем данные для модели**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.25, random_state=42)

# %% [markdown]
# ## Применение модели<a class="anchor" id="practice"></a>

# %% [markdown]
# Отбор параметров для модели **model_ctb**:
#
# *params_c = {'n_estimators':randint(0,1000),
#           'max_depth':randint(0,100),
#            'od_wait' : randint(0,10),
#            'best_model_min_trees': randint(0,100),
#            'random_state': randint(0,200),
#             'loss_function':['Logloss','CrossEntropy'],
#              'od_type':['IncToDec','Iter'],
#            'l2_leaf_reg':randint(0,100),
#             'learning_rate':uniform(loc=0,scale=10)
#             'use_best_model':[True,False]
#            }
# cv=KFold(n_splits=3, random_state=21, shuffle=True)*
#
# производился вот такой моделью:
#
# *rs = RandomizedSearchCV(model_ctb, params_c, scoring='f1', cv=cv, n_jobs=-1)
# rs.fit(X_train, y_train)
# rs.best_params_,rs.best_score_*
#
# Она затратна по времени, поэтому привожу её в виде комментария.

# %%
model_ctb = CatBoostClassifier(best_model_min_trees=35, 
                               l2_leaf_reg=95,
                               loss_function ='Logloss',
                               max_depth= 11, 
                               n_estimators=750,
                               od_wait=2,
                               random_state=162,
                               silent=True,
                               learning_rate=0.02)

model_ctb.fit(X_resampled, y_resampled)


y_train_pred = model_ctb.predict(X_train)
y_test_pred = model_ctb.predict(X_test)
y_test_pred_probs = model_ctb.predict_proba(X_test)

get_classification_report(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.89      0.91      4074
#          1.0       0.75      0.82      0.78      1551
#
#     accuracy                           0.87      5625
#    macro avg       0.84      0.86      0.85      5625
# weighted avg       0.88      0.87      0.88      5625
#
# TEST
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.89      0.91      1313
#          1.0       0.77      0.84      0.80       562
#
#     accuracy                           0.87      1875
#    macro avg       0.85      0.86      0.85      1875
# weighted avg       0.88      0.87      0.88      1875
#
# CONFUSION MATRIX
#
# col_0            0.0  1.0
# Credit Default
# 0.0             1169  144
# 1.0               92  470

# %% [markdown]
# * Получена модель со значением F1 > 0.5

# %%
y_test_pred_probs = model_ctb.predict_proba(X_test)

# %%
show_proba_calibration_plots(y_test_pred_probs[:, 1], y_test)

# %% [markdown]
# **Сохранение модели**

# %%
with open(MODEL_FILE_PATH, 'wb') as file:
    pickle.dump(model_ctb, file)

# %% [markdown]
# **Работа с тестовыми данными**

# %%
test = pd.read_csv(TEST_PATH)

# %%
test=prepare_label(test)
test=missing_imputer(test)
test=standart_df(test,feats)
view_matrix(test)
# Out:
# '/usr/local/share/datasets/matrix_sorted.png'
#    Home Ownership  Annual Income  Years in current job  Tax Liens  \
# 0         1.14546      -2.086484              0.007563        0.0
# 1         1.14546      -1.248252             -1.174187        0.0
# 2        -0.96094      -0.240587             -0.287874        0.0
# 3        -0.96094      -0.166413             -0.878749        0.0
# 4        -0.96094       1.060073              0.598438        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                -0.450224                -0.803220            -0.323879
# 1                -1.068551                 1.981755            -0.433044
# 2                -0.244115                -0.637776            -0.334707
# 3                 0.992538                -0.182805            -0.168202
# 4                -0.038006                 0.727138             0.328576
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                  -0.289398                     70.000000           0.0
# 1                  -0.289398                      8.000000           0.0
# 2                  -0.289398                     47.808515           0.0
# 3                  -0.289398                     70.000000           0.0
# 4                  -0.289398                     41.778007           0.0
#
#     Purpose      Term  Current Loan Amount  Current Credit Balance  \
# 0 -0.369834  0.585973            -0.371832               -0.503642
# 1  0.121966  0.585973            -0.374441               -0.661931
# 2 -0.369834  0.585973            -0.370663               -0.396341
# 3 -0.369834  0.585973            -0.370129               -0.219968
# 4 -0.369834 -1.706565            -0.352759                0.341051
#
#    Monthly Debt  Credit Score
# 0     -0.992788      2.405096
# 1     -1.382250     -0.324899
# 2      0.039653      3.456690
# 3      0.804714     -0.301844
# 4      2.108349     -0.320864
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
# Home Ownership                  2500 non-null float64
# Annual Income                   2500 non-null float64
# Years in current job            2500 non-null float64
# Tax Liens                       2500 non-null float64
# Number of Open Accounts         2500 non-null float64
# Years of Credit History         2500 non-null float64
# Maximum Open Credit             2500 non-null float64
# Number of Credit Problems       2500 non-null float64
# Months since last delinquent    2500 non-null float64
# Bankruptcies                    2500 non-null float64
# Purpose                         2500 non-null float64
# Term                            2500 non-null float64
# Current Loan Amount             2500 non-null float64
# Current Credit Balance          2500 non-null float64
# Monthly Debt                    2500 non-null float64
# Credit Score                    2500 non-null float64
# dtypes: float64(16)
# memory usage: 312.6 KB
# Home Ownership                  0
# Annual Income                   0
# Years in current job            0
# Tax Liens                       0
# Number of Open Accounts         0
# Years of Credit History         0
# Maximum Open Credit             0
# Number of Credit Problems       0
# Months since last delinquent    0
# Bankruptcies                    0
# Purpose                         0
# Term                            0
# Current Loan Amount             0
# Current Credit Balance          0
# Monthly Debt                    0
# Credit Score                    0
# dtype: int64 None

# %% [markdown]
# **Финальный датасет**

# %%
test['Credit default'] = model_ctb.predict(test.loc[:, feats])

test.loc[:, ['Id', 'Credit default']].to_csv('MTabunov_predictions_210220.csv', index=None)
